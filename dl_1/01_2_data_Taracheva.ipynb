# %% [markdown]
# # Подготовка данных для обучения моделей
#
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * https://scikit-learn.org/stable/modules/compose.html#pipeline-chaining-estimators
# * https://pytorch.org/docs/stable/data.html
# * https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# * Deep Learning with PyTorch (2020) Авторы: Eli Stevens, Luca Antiga, Thomas Viehmann

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Создайте синтетический датасет для задачи регрессии и представьте его в виде `torch.utils.data.Dataset`

# %%
import torch
from torch.utils.data import Dataset
class CustomDataset(Dataset):
    def __init__(self, w_true, n_features, n_objects):
        self.X = (torch.rand(n_objects, n_features) - 0.5) * 10
        self.X *= (torch.arange(n_features) * 2 + 1)
        self.Y = self.X @ w_true + torch.randn(n_objects)

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, item):
        return self.X[item], self.Y[item]

# %%
n_features = 2
n_objects = 300
w_true = torch.randn(n_features)
dataset = CustomDataset(w_true, n_features, n_objects)

# %%
len(dataset)
# Out:
# 300

# %%
dataset[0]
# Out:
# (tensor([1.0584, 7.6576]), tensor(-3.6397))

# %% [markdown]
# ## Задачи для самостоятельного решения

# %% [markdown]
# <p class="task" id="1"></p>
#
# 1\. Считайте файл `bank-full.csv` ([источник](https://www.kaggle.com/datasets/hariharanpavan/bank-marketing-dataset-analysis-classification)) в виде `pd.DataFrame`.
#
# Опишите класс `BankDatasetBase`. Решение должно удовлетворять следующим критериям:
#
# * класс наследуется от `torch.utils.data.Dataset`;
# * при создании объекта в конструктор передается набор данных в виде `pd.DataFrame`;
# * объекты класса имеют поля `X` и `y` с признаками и метками соответственно;
# * класс реализует интерфейс последовательностей (`__getitem__` + `__len__`);
# * `obj[i]` возвращает кортеж, содержащий `i`-ую строку из `obj.X` (серию) и `i`-ую строку из `obj.y` (строку).
#
# Создайте объект класса `BankDatasetBase` и продемонстрируйте работоспособность.
#
# - [ ] Проверено на семинаре

# %%
class BankDatasetBase(Dataset):
    def __init__(self, data: pd.DataFrame) -> None:
        self.X = data.drop(columns=['y'])
        self.y = data['y']

    def __getitem__(self, idx: int) -> tuple:
        return self.X.iloc[idx], self.y.iloc[idx]

    def __len__(self) -> int:
        return len(self.X)

# %%
import pandas as pd
df = pd.read_csv('bank-full.csv', sep=',')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank_dataset = BankDatasetBase(data=df)
len(bank_dataset)
# Out:
# 45211

# %%
bank_dataset[0]
# Out:
# (age                  58
#  job          management
#  marital         married
#  education      tertiary
#  default              no
#  balance            2143
#  housing             yes
#  loan                 no
#  contact         unknown
#  day                   5
#  month               may
#  duration            261
#  campaign              1
#  pdays                -1
#  previous              0
#  poutcome        unknown
#  Name: 0, dtype: object,
#  'no')

# %% [markdown]
# <p class="task" id="2"></p>
#
# 2\. Опишите класс `BankDataset`. Решение должно удовлетворять всем критериям из предыдущего задания, а также:
# * при создании объекта в конструктор может быть передан необязательные аргументы `transform` и `target_transform`;
# * если аргумент `transform` был передан, то при получении `i`-го элемента, нужно вызвать `transform(x)` и вернуть полученный результат.
# * если аргумент `target_transform` был передан, то при получении `i`-го элемента, нужно вызвать `target_transform(y)` и вернуть полученный результат.
#
# Создайте объект класса `BankDataset` и продемонстрируйте работоспособность (без передачи `target_transform` и `transform`).
#
# - [ ] Проверено на семинаре

# %%
from typing import Callable

class BankDataset(Dataset):
    def __init__(
            self,
            data: pd.DataFrame,
            transform: Callable | None = None,
            target_transform: Callable | None = None
    ) -> None:
        self.X = data.drop(columns=['y'])
        self.y = data['y']
        self.transform = transform
        self.target_transform = target_transform
    def __getitem__(self, idx: int) -> tuple:
        x = self.X.iloc[idx]
        y = self.y.iloc[idx]

        if self.transform:
            x = self.transform(x)
        if self.target_transform:
            y = self.target_transform(y)

        return x, y

    def __len__(self) -> int:
        return len(self.X)

# %%
df = pd.read_csv('bank-full.csv', sep=',')
bank_dataset_no_transform = BankDataset(data=df)
len(bank_dataset_no_transform)
# Out:
# 45211

# %%
bank_dataset_no_transform[0]
# Out:
# (age                  58
#  job          management
#  marital         married
#  education      tertiary
#  default              no
#  balance            2143
#  housing             yes
#  loan                 no
#  contact         unknown
#  day                   5
#  month               may
#  duration            261
#  campaign              1
#  pdays                -1
#  previous              0
#  poutcome        unknown
#  Name: 0, dtype: object,
#  'no')

# %% [markdown]
# <p class="task" id="3"></p>
#
# 3\. Опишите класс `OrdinalEncoderTransform`. Решение должно удовлетворять следующим критериям:
#
# * при создании объекта в конструктор передаются названия нечисловых столбцов в датасете
# * класс реализует интерфейс `Callable` (`__call__`); метод `__call__` имеет один параметр (признаки) и возвращает набор признаков, в котором нечисловые характеристики закодированы целыми числами;
# * состояние объекта (индексы для кодирования) обновляется в момент очередного вызова `__call__` (т.е. все данные сразу никогда не передаются никакому методу объекта).
#
# Продемонстрируйте работоспособность, создав объект `BankDataset` и передав при создании объект класса `OrdinalEncoderTransform`.
#
# - [ ] Проверено на семинаре

# %%
class Transform:
    pass

# %%
class OrdinalEncoderTransform:
    def __init__(self, category_columns: list[str]) -> None:
        self.category_columns = category_columns
        self.encoding_dict = {}

    def __call__(self, x: pd.Series) -> pd.Series:
        x_transformed = x.copy()

        for col in self.category_columns:
            if col in x.index:
                value = x[col]
                if col not in self.encoding_dict:
                    self.encoding_dict[col] = {}
                if value not in self.encoding_dict[col]:
                    self.encoding_dict[col][value] = len(self.encoding_dict[col])

                x_transformed[col] = self.encoding_dict[col][value]

        return x_transformed

    def get_encoding_info(self) -> dict:
        return self.encoding_dict.copy()

# %%
df = pd.read_csv('bank-full.csv', sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
category_columns = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']
encoder = OrdinalEncoderTransform(category_columns)

bank_dataset_encoded = BankDataset(data=df, transform=encoder)

indices_to_check = [0, 24, 100]
for idx in indices_to_check:
    print(f"строка {idx}")
    print("До кодирования:")
    print(bank_dataset_no_transform[idx][0][category_columns])
    print("После кодирования:")
    print(bank_dataset_encoded[idx][0][category_columns])
# Out:
# строка 0
# До кодирования:
# job          management
# marital         married
# education      tertiary
# default              no
# housing             yes
# loan                 no
# contact         unknown
# month               may
# poutcome        unknown
# Name: 0, dtype: object
# После кодирования:
# job          0
# marital      0
# education    0
# default      0
# housing      0
# loan         0
# contact      0
# month        0
# poutcome     0
# Name: 0, dtype: object
# строка 24
# До кодирования:
# job          retired
# marital      married
# education    primary
# default           no
# housing          yes
# loan             yes
# contact      unknown
# month            may
# poutcome     unknown
# Name: 24, dtype: object
# После кодирования:
# job          1
# marital      0
# education    1
# default      0
# housing      0
# loan         1
# contact      0
# month        0
# poutcome     0
# Name: 24, dtype: object
# строка 100
# До кодирования:
# job          blue-collar
# marital          married
# education      secondary
# default               no
# housing              yes
# loan                  no
# contact          unknown
# month                may
# poutcome         unknown
# Name: 100, dtype: object
# После кодирования:
# job          2
# marital      0
# education    2
# default      0
# housing      0
# loan         0
# contact      0
# month        0
# poutcome     0
# Name: 100, dtype: object

# %%
print("Итоговое кодирование")
print(encoder.get_encoding_info())
# Out:
# Итоговое кодирование
# {'job': {'management': 0, 'retired': 1, 'blue-collar': 2}, 'marital': {'married': 0}, 'education': {'tertiary': 0, 'primary': 1, 'secondary': 2}, 'default': {'no': 0}, 'housing': {'yes': 0}, 'loan': {'no': 0, 'yes': 1}, 'contact': {'unknown': 0}, 'month': {'may': 0}, 'poutcome': {'unknown': 0}}

# %% [markdown]
# <p class="task" id="4"></p>
#
# 4\. Опишите класс `LabelEncoderTransform`. Решение должно удовлетворять следующим критериям:
#
# * класс реализует интерфейс `Callable` (`__call__`); метод `__call__` имеет один параметр (строку) и возвращает целое число, соответствующее этой строке;
# * состояние объекта (индексы для кодирования) обновляется в момент очередного вызова `__call__` (т.е. все данные сразу никогда не передаются никакому методу объекта).
#
# Продемонстрируйте работоспособность, создав объект `BankDataset` и передав при создании объекта в качестве аргумента `target_transform` объект класса `LabelEncoderTransform`.
#
# - [ ] Проверено на семинаре

# %%
class LabelEncoderTransform:
    def __init__(self) -> None:
        self.encoding_dict = {}
        self.next_index = 0

    def __call__(self, label: str) -> int:
        if label not in self.encoding_dict:
            self.encoding_dict[label] = self.next_index
            self.next_index += 1
        return self.encoding_dict[label]

    def get_encoding_info(self) -> dict:
        return self.encoding_dict.copy()

# %%
label_encoder = LabelEncoderTransform()
bank_dataset_label_encoded = BankDataset(
    data=df,
    target_transform=label_encoder
)

for i in range(len(bank_dataset_label_encoded)):
    x, y_encoded = bank_dataset_label_encoded[i]
    x, y_original = bank_dataset_no_transform[i]
    print(f"Элемент {i}: y до:'{y_original}', после:{y_encoded}")

print("Информация о кодировании меток:")
print(label_encoder.get_encoding_info())
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Элемент 40213: y до:'no', после:0
# Элемент 40214: y до:'no', после:0
# Элемент 40215: y до:'no', после:0
# Элемент 40216: y до:'no', после:0
# Элемент 40217: y до:'yes', после:1
# Элемент 40218: y до:'yes', после:1
# Элемент 40219: y до:'yes', после:1
# Элемент 40220: y до:'yes', после:1
# Элемент 40221: y до:'no', после:0
# Элемент 40222: y до:'yes', после:1
# Элемент 40223: y до:'no', после:0
# Элемент 40224: y до:'no', после:0
# Элемент 40225: y до:'no', после:0
# Элемент 40226: y до:'yes', после:1
# Элемент 40227: y до:'no', после:0
# Элемент 40228: y до:'yes', после:1
# Элемент 40229: y до:'no', после:0
# Элемент 40230: y до:'no', после:0
# Элемент 40231: y до:'yes', после:1
# Элемент 40232: y до:'no', после:0
# Элемент 40233: y до:'yes', после:1
# Элемент 40234: y до:'no', после:0
# Элемент 40235: y до:'no', после:0
# Элемент 40236: y до:'no', после:0
# Элемент 40237: y до:'no', после:0
# Элемент 40238: y до:'no', после:0
# Элемент 40239: y до:'no', после:0
# Элемент 40240: y до:'no', после:0
# Элемент 40241: y до:'no', после:0
# Элемент 40242: y до:'no', после:0
# Элемент 40243: y до:'no', после:0
# Элемент 40244: y до:'yes', после:1
# Элемент 40245: y до:'yes', после:1
# Элемент 40246: y до:'no', после:0
# Элемент 40247: y до:'yes', после:1
# Элемент 40248: y до:'no', после:0
# Элемент 40249: y до:'yes', после:1
# Элемент 40250: y до:'no', после:0
# Элемент 40251: y до:'no', после:0
# Элемент 40252: y до:'no', после:0
# Элемент 40253: y до:'yes', после:1
# Элемент 40254: y до:'no', после:0
# Элемент 40255: y до:'no', после:0
# Элемент 40256: y до:'no', после:0
# Элемент 40257: y до:'yes', после:1
# Элемент 40258: y до:'yes', после:1
# Элемент 40259: y до:'no', после:0
# Элемент 40260: y до:'yes', после:1
# Элемент 40261: y до:'no', после:0
# Элемент 40262: y до:'yes', после:1
# Элемент 40263: y до:'no', после:0
# Элемент 40264: y до:'yes', после:1
# Элемент 40265: y до:'no', после:0
# Элемент 40266: y до:'no', после:0
# Элемент 40267: y до:'yes', после:1
# Элемент 40268: y до:'no', после:0
# Элемент 40269: y до:'no', после:0
# Элемент 40270: y до:'yes', после:1
# Элемент 40271: y до:'no', после:0
# Элемент 40272: y до:'no', после:0
# Элемент 40273: y до:'no', после:0
# Элемент 40274: y до:'yes', после:1
# Элемент 40275: y до:'yes', после:1
# Элемент 40276: y до:'yes', после:1
# Элемент 40277: y до:'yes', после:1
# Элемент 40278: y до:'yes', после:1
# Элемент 40279: y до:'yes', после:1
# Элемент 40280: y до:'no', после:0
# Элемент 40281: y до:'no', после:0
# Элемент 40282: y до:'yes', после:1
# Элемент 40283: y до:'no', после:0
# Элемент 40284: y до:'no', после:0
# Элемент 40285: y до:'no', после:0
# Элемент 40286: y до:'no', после:0
# Элемент 40287: y до:'no', после:0
# Элемент 40288: y до:'no', после:0
# Элемент 40289: y до:'yes', после:1
# Элемент 40290: y до:'no', после:0
# Элемент 40291: y до:'no', после:0
# Элемент 40292: y до:'no', после:0
# Элемент 40293: y до:'no', после:0
# Элемент 40294: y до:'yes', после:1
# Элемент 40295: y до:'no', после:0
# Элемент 40296: y до:'no', после:0
# Элемент 40297: y до:'no', после:0
# Элемент 40298: y до:'yes', после:1
# Элемент 40299: y до:'yes', после:1
# Элемент 40300: y до:'no', после:0
# Элемент 40301: y до:'yes', после:1
# Элемент 40302: y до:'yes', после:1
# Элемент 40303: y до:'no', после:0
# Элемент 40304: y до:'no', после:0
# Элемент 40305: y до:'yes', после:1
# Элемент 40306: y до:'no', после:0
# Элемент 40307: y до:'no', после:0
# Элемент 40308: y до:'yes', после:1
# Элемент 40309: y до:'no', после:0
# Элемент 40310: y до:'no', после:0
# Элемент 40311: y до:'no', после:0
# Элемент 40312: y до:'no', после:0
# Элемент 40313: y до:'no', после:0
# Элемент 40314: y до:'no', после:0
# Элемент 40315: y до:'no', после:0
# Элемент 40316: y до:'no', после:0
# Элемент 40317: y до:'no', после:0
# Элемент 40318: y до:'no', после:0
# Элемент 40319: y до:'no', после:0
# Элемент 40320: y до:'no', после:0
# Элемент 40321: y до:'no', после:0
# Элемент 40322: y до:'no', после:0
# Элемент 40323: y до:'yes', после:1
# Элемент 40324: y до:'no', после:0
# Элемент 40325: y до:'no', после:0
# Элемент 40326: y до:'yes', после:1
# Элемент 40327: y до:'no', после:0
# Элемент 40328: y до:'no', после:0
# Элемент 40329: y до:'no', после:0
# Элемент 40330: y до:'yes', после:1
# Элемент 40331: y до:'no', после:0
# Элемент 40332: y до:'no', после:0
# Элемент 40333: y до:'no', после:0
# Элемент 40334: y до:'yes', после:1
# Элемент 40335: y до:'no', после:0
# Элемент 40336: y до:'no', после:0
# Элемент 40337: y до:'yes', после:1
# Элемент 40338: y до:'no', после:0
# Элемент 40339: y до:'yes', после:1
# Элемент 40340: y до:'no', после:0
# Элемент 40341: y до:'no', после:0
# Элемент 40342: y до:'yes', после:1
# Элемент 40343: y до:'no', после:0
# Элемент 40344: y до:'yes', после:1
# Элемент 40345: y до:'yes', после:1
# Элемент 40346: y до:'yes', после:1
# Элемент 40347: y до:'yes', после:1
# Элемент 40348: y до:'no', после:0
# Элемент 40349: y до:'yes', после:1
# Элемент 40350: y до:'yes', после:1
# Элемент 40351: y до:'no', после:0
# Элемент 40352: y до:'no', после:0
# Элемент 40353: y до:'no', после:0
# Элемент 40354: y до:'no', после:0
# Элемент 40355: y до:'yes', после:1
# Элемент 40356: y до:'no', после:0
# Элемент 40357: y до:'no', после:0
# Элемент 40358: y до:'no', после:0
# Элемент 40359: y до:'no', после:0
# Элемент 40360: y до:'no', после:0
# Элемент 40361: y до:'no', после:0
# Элемент 40362: y до:'no', после:0
# Элемент 40363: y до:'yes', после:1
# Элемент 40364: y до:'no', после:0
# Элемент 40365: y до:'no', после:0
# Элемент 40366: y до:'yes', после:1
# Элемент 40367: y до:'no', после:0
# Элемент 40368: y до:'no', после:0
# Элемент 40369: y до:'no', после:0
# Элемент 40370: y до:'yes', после:1
# Элемент 40371: y до:'no', после:0
# Элемент 40372: y до:'no', после:0
# Элемент 40373: y до:'yes', после:1
# Элемент 40374: y до:'no', после:0
# Элемент 40375: y до:'yes', после:1
# Элемент 40376: y до:'no', после:0
# Элемент 40377: y до:'no', после:0
# Элемент 40378: y до:'no', после:0
# Элемент 40379: y до:'yes', после:1
# Элемент 40380: y до:'no', после:0
# Элемент 40381: y до:'no', после:0
# Элемент 40382: y до:'no', после:0
# Элемент 40383: y до:'yes', после:1
# Элемент 40384: y до:'no', после:0
# Элемент 40385: y до:'no', после:0
# Элемент 40386: y до:'yes', после:1
# Элемент 40387: y до:'no', после:0
# Элемент 40388: y до:'no', после:0
# Элемент 40389: y до:'no', после:0
# Элемент 40390: y до:'no', после:0
# Элемент 40391: y до:'no', после:0
# Элемент 40392: y до:'yes', после:1
# Элемент 40393: y до:'yes', после:1
# Элемент 40394: y до:'yes', после:1
# Элемент 40395: y до:'no', после:0
# Элемент 40396: y до:'yes', после:1
# Элемент 40397: y до:'no', после:0
# Элемент 40398: y до:'no', после:0
# Элемент 40399: y до:'no', после:0
# Элемент 40400: y до:'no', после:0
# Элемент 40401: y до:'yes', после:1
# Элемент 40402: y до:'yes', после:1
# Элемент 40403: y до:'yes', после:1
# Элемент 40404: y до:'yes', после:1
# Элемент 40405: y до:'yes', после:1
# Элемент 40406: y до:'no', после:0
# Элемент 40407: y до:'no', после:0
# Элемент 40408: y до:'yes', после:1
# Элемент 40409: y до:'no', после:0
# Элемент 40410: y до:'no', после:0
# Элемент 40411: y до:'yes', после:1
# Элемент 40412: y до:'yes', после:1
# Элемент 40413: y до:'yes', после:1
# Элемент 40414: y до:'yes', после:1
# Элемент 40415: y до:'no', после:0
# Элемент 40416: y до:'no', после:0
# Элемент 40417: y до:'yes', после:1
# Элемент 40418: y до:'no', после:0
# Элемент 40419: y до:'yes', после:1
# Элемент 40420: y до:'no', после:0
# Элемент 40421: y до:'yes', после:1
# Элемент 40422: y до:'yes', после:1
# Элемент 40423: y до:'no', после:0
# Элемент 40424: y до:'no', после:0
# Элемент 40425: y до:'no', после:0
# Элемент 40426: y до:'no', после:0
# Элемент 40427: y до:'no', после:0
# Элемент 40428: y до:'no', после:0
# Элемент 40429: y до:'no', после:0
# Элемент 40430: y до:'no', после:0
# Элемент 40431: y до:'no', после:0
# Элемент 40432: y до:'no', после:0
# Элемент 40433: y до:'no', после:0
# Элемент 40434: y до:'yes', после:1
# Элемент 40435: y до:'no', после:0
# Элемент 40436: y до:'yes', после:1
# Элемент 40437: y до:'yes', после:1
# Элемент 40438: y до:'yes', после:1
# Элемент 40439: y до:'yes', после:1
# Элемент 40440: y до:'yes', после:1
# Элемент 40441: y до:'yes', после:1
# Элемент 40442: y до:'yes', после:1
# Элемент 40443: y до:'yes', после:1
# Элемент 40444: y до:'yes', после:1
# Элемент 40445: y до:'no', после:0
# Элемент 40446: y до:'yes', после:1
# Элемент 40447: y до:'yes', после:1
# Элемент 40448: y до:'no', после:0
# Элемент 40449: y до:'yes', после:1
# Элемент 40450: y до:'no', после:0
# Элемент 40451: y до:'yes', после:1
# Элемент 40452: y до:'no', после:0
# Элемент 40453: y до:'yes', после:1
# Элемент 40454: y до:'no', после:0
# Элемент 40455: y до:'no', после:0
# Элемент 40456: y до:'yes', после:1
# Элемент 40457: y до:'yes', после:1
# Элемент 40458: y до:'no', после:0
# Элемент 40459: y до:'yes', после:1
# Элемент 40460: y до:'no', после:0
# Элемент 40461: y до:'yes', после:1
# Элемент 40462: y до:'no', после:0
# Элемент 40463: y до:'no', после:0
# Элемент 40464: y до:'no', после:0
# Элемент 40465: y до:'no', после:0
# Элемент 40466: y до:'no', после:0
# Элемент 40467: y до:'no', после:0
# Элемент 40468: y до:'no', после:0
# Элемент 40469: y до:'no', после:0
# Элемент 40470: y до:'no', после:0
# Элемент 40471: y до:'no', после:0
# Элемент 40472: y до:'yes', после:1
# Элемент 40473: y до:'no', после:0
# Элемент 40474: y до:'no', после:0
# Элемент 40475: y до:'no', после:0
# Элемент 40476: y до:'no', после:0
# Элемент 40477: y до:'yes', после:1
# Элемент 40478: y до:'yes', после:1
# Элемент 40479: y до:'yes', после:1
# Элемент 40480: y до:'no', после:0
# Элемент 40481: y до:'yes', после:1
# Элемент 40482: y до:'no', после:0
# Элемент 40483: y до:'no', после:0
# Элемент 40484: y до:'no', после:0
# Элемент 40485: y до:'no', после:0
# Элемент 40486: y до:'yes', после:1
# Элемент 40487: y до:'no', после:0
# Элемент 40488: y до:'yes', после:1
# Элемент 40489: y до:'yes', после:1
# Элемент 40490: y до:'yes', после:1
# Элемент 40491: y до:'no', после:0
# Элемент 40492: y до:'no', после:0
# Элемент 40493: y до:'no', после:0
# Элемент 40494: y до:'no', после:0
# Элемент 40495: y до:'yes', после:1
# Элемент 40496: y до:'no', после:0
# Элемент 40497: y до:'yes', после:1
# Элемент 40498: y до:'no', после:0
# Элемент 40499: y до:'no', после:0
# Элемент 40500: y до:'no', после:0
# Элемент 40501: y до:'no', после:0
# Элемент 40502: y до:'yes', после:1
# Элемент 40503: y до:'no', после:0
# Элемент 40504: y до:'yes', после:1
# Элемент 40505: y до:'no', после:0
# Элемент 40506: y до:'yes', после:1
# Элемент 40507: y до:'no', после:0
# Элемент 40508: y до:'no', после:0
# Элемент 40509: y до:'yes', после:1
# Элемент 40510: y до:'no', после:0
# Элемент 40511: y до:'no', после:0
# Элемент 40512: y до:'no', после:0
# Элемент 40513: y до:'yes', после:1
# Элемент 40514: y до:'yes', после:1
# Элемент 40515: y до:'no', после:0
# Элемент 40516: y до:'yes', после:1
# Элемент 40517: y до:'no', после:0
# Элемент 40518: y до:'no', после:0
# Элемент 40519: y до:'no', после:0
# Элемент 40520: y до:'no', после:0
# Элемент 40521: y до:'yes', после:1
# Элемент 40522: y до:'yes', после:1
# Элемент 40523: y до:'yes', после:1
# Элемент 40524: y до:'yes', после:1
# Элемент 40525: y до:'no', после:0
# Элемент 40526: y до:'yes', после:1
# Элемент 40527: y до:'no', после:0
# Элемент 40528: y до:'yes', после:1
# Элемент 40529: y до:'no', после:0
# Элемент 40530: y до:'no', после:0
# Элемент 40531: y до:'no', после:0
# Элемент 40532: y до:'no', после:0
# Элемент 40533: y до:'no', после:0
# Элемент 40534: y до:'no', после:0
# Элемент 40535: y до:'no', после:0
# Элемент 40536: y до:'no', после:0
# Элемент 40537: y до:'yes', после:1
# Элемент 40538: y до:'no', после:0
# Элемент 40539: y до:'no', после:0
# Элемент 40540: y до:'no', после:0
# Элемент 40541: y до:'no', после:0
# Элемент 40542: y до:'no', после:0
# Элемент 40543: y до:'yes', после:1
# Элемент 40544: y до:'no', после:0
# Элемент 40545: y до:'no', после:0
# Элемент 40546: y до:'yes', после:1
# Элемент 40547: y до:'no', после:0
# Элемент 40548: y до:'no', после:0
# Элемент 40549: y до:'no', после:0
# Элемент 40550: y до:'no', после:0
# Элемент 40551: y до:'no', после:0
# Элемент 40552: y до:'yes', после:1
# Элемент 40553: y до:'no', после:0
# Элемент 40554: y до:'no', после:0
# Элемент 40555: y до:'yes', после:1
# Элемент 40556: y до:'no', после:0
# Элемент 40557: y до:'yes', после:1
# Элемент 40558: y до:'no', после:0
# Элемент 40559: y до:'yes', после:1
# Элемент 40560: y до:'no', после:0
# Элемент 40561: y до:'no', после:0
# Элемент 40562: y до:'no', после:0
# Элемент 40563: y до:'no', после:0
# Элемент 40564: y до:'yes', после:1
# Элемент 40565: y до:'no', после:0
# Элемент 40566: y до:'yes', после:1
# Элемент 40567: y до:'no', после:0
# Элемент 40568: y до:'no', после:0
# Элемент 40569: y до:'yes', после:1
# Элемент 40570: y до:'yes', после:1
# Элемент 40571: y до:'no', после:0
# Элемент 40572: y до:'no', после:0
# Элемент 40573: y до:'no', после:0
# Элемент 40574: y до:'yes', после:1
# Элемент 40575: y до:'no', после:0
# Элемент 40576: y до:'no', после:0
# Элемент 40577: y до:'no', после:0
# Элемент 40578: y до:'no', после:0
# Элемент 40579: y до:'no', после:0
# Элемент 40580: y до:'no', после:0
# Элемент 40581: y до:'no', после:0
# Элемент 40582: y до:'no', после:0
# Элемент 40583: y до:'yes', после:1
# Элемент 40584: y до:'no', после:0
# Элемент 40585: y до:'no', после:0
# Элемент 40586: y до:'no', после:0
# Элемент 40587: y до:'no', после:0
# Элемент 40588: y до:'yes', после:1
# Элемент 40589: y до:'no', после:0
# Элемент 40590: y до:'yes', после:1
# Элемент 40591: y до:'no', после:0
# Элемент 40592: y до:'no', после:0
# Элемент 40593: y до:'no', после:0
# Элемент 40594: y до:'yes', после:1
# Элемент 40595: y до:'no', после:0
# Элемент 40596: y до:'yes', после:1
# Элемент 40597: y до:'no', после:0
# Элемент 40598: y до:'no', после:0
# Элемент 40599: y до:'no', после:0
# Элемент 40600: y до:'no', после:0
# Элемент 40601: y до:'no', после:0
# Элемент 40602: y до:'no', после:0
# Элемент 40603: y до:'no', после:0
# Элемент 40604: y до:'no', после:0
# Элемент 40605: y до:'no', после:0
# Элемент 40606: y до:'no', после:0
# Элемент 40607: y до:'no', после:0
# Элемент 40608: y до:'no', после:0
# Элемент 40609: y до:'yes', после:1
# Элемент 40610: y до:'yes', после:1
# Элемент 40611: y до:'yes', после:1
# Элемент 40612: y до:'no', после:0
# Элемент 40613: y до:'yes', после:1
# Элемент 40614: y до:'no', после:0
# Элемент 40615: y до:'yes', после:1
# Элемент 40616: y до:'yes', после:1
# Элемент 40617: y до:'yes', после:1
# Элемент 40618: y до:'yes', после:1
# Элемент 40619: y до:'no', после:0
# Элемент 40620: y до:'no', после:0
# Элемент 40621: y до:'no', после:0
# Элемент 40622: y до:'yes', после:1
# Элемент 40623: y до:'no', после:0
# Элемент 40624: y до:'yes', после:1
# Элемент 40625: y до:'yes', после:1
# Элемент 40626: y до:'no', после:0
# Элемент 40627: y до:'no', после:0
# Элемент 40628: y до:'no', после:0
# Элемент 40629: y до:'yes', после:1
# Элемент 40630: y до:'yes', после:1
# Элемент 40631: y до:'yes', после:1
# Элемент 40632: y до:'yes', после:1
# Элемент 40633: y до:'no', после:0
# Элемент 40634: y до:'yes', после:1
# Элемент 40635: y до:'yes', после:1
# Элемент 40636: y до:'yes', после:1
# Элемент 40637: y до:'no', после:0
# Элемент 40638: y до:'no', после:0
# Элемент 40639: y до:'no', после:0
# Элемент 40640: y до:'yes', после:1
# Элемент 40641: y до:'no', после:0
# Элемент 40642: y до:'yes', после:1
# Элемент 40643: y до:'yes', после:1
# Элемент 40644: y до:'no', после:0
# Элемент 40645: y до:'no', после:0
# Элемент 40646: y до:'no', после:0
# Элемент 40647: y до:'yes', после:1
# Элемент 40648: y до:'yes', после:1
# Элемент 40649: y до:'no', после:0
# Элемент 40650: y до:'yes', после:1
# Элемент 40651: y до:'yes', после:1
# Элемент 40652: y до:'no', после:0
# Элемент 40653: y до:'yes', после:1
# Элемент 40654: y до:'no', после:0
# Элемент 40655: y до:'no', после:0
# Элемент 40656: y до:'yes', после:1
# Элемент 40657: y до:'no', после:0
# Элемент 40658: y до:'yes', после:1
# Элемент 40659: y до:'no', после:0
# Элемент 40660: y до:'no', после:0
# Элемент 40661: y до:'no', после:0
# Элемент 40662: y до:'no', после:0
# Элемент 40663: y до:'no', после:0
# Элемент 40664: y до:'no', после:0
# Элемент 40665: y до:'no', после:0
# Элемент 40666: y до:'no', после:0
# Элемент 40667: y до:'no', после:0
# Элемент 40668: y до:'yes', после:1
# Элемент 40669: y до:'no', после:0
# Элемент 40670: y до:'yes', после:1
# Элемент 40671: y до:'no', после:0
# Элемент 40672: y до:'yes', после:1
# Элемент 40673: y до:'no', после:0
# Элемент 40674: y до:'no', после:0
# Элемент 40675: y до:'no', после:0
# Элемент 40676: y до:'yes', после:1
# Элемент 40677: y до:'no', после:0
# Элемент 40678: y до:'no', после:0
# Элемент 40679: y до:'yes', после:1
# Элемент 40680: y до:'yes', после:1
# Элемент 40681: y до:'yes', после:1
# Элемент 40682: y до:'no', после:0
# Элемент 40683: y до:'yes', после:1
# Элемент 40684: y до:'no', после:0
# Элемент 40685: y до:'yes', после:1
# Элемент 40686: y до:'yes', после:1
# Элемент 40687: y до:'yes', после:1
# Элемент 40688: y до:'no', после:0
# Элемент 40689: y до:'yes', после:1
# Элемент 40690: y до:'yes', после:1
# Элемент 40691: y до:'no', после:0
# Элемент 40692: y до:'no', после:0
# Элемент 40693: y до:'no', после:0
# Элемент 40694: y до:'no', после:0
# Элемент 40695: y до:'no', после:0
# Элемент 40696: y до:'yes', после:1
# Элемент 40697: y до:'yes', после:1
# Элемент 40698: y до:'yes', после:1
# Элемент 40699: y до:'yes', после:1
# Элемент 40700: y до:'no', после:0
# Элемент 40701: y до:'yes', после:1
# Элемент 40702: y до:'yes', после:1
# Элемент 40703: y до:'no', после:0
# Элемент 40704: y до:'no', после:0
# Элемент 40705: y до:'yes', после:1
# Элемент 40706: y до:'yes', после:1
# Элемент 40707: y до:'yes', после:1
# Элемент 40708: y до:'no', после:0
# Элемент 40709: y до:'no', после:0
# Элемент 40710: y до:'yes', после:1
# Элемент 40711: y до:'no', после:0
# Элемент 40712: y до:'no', после:0
# Элемент 40713: y до:'no', после:0
# Элемент 40714: y до:'no', после:0
# Элемент 40715: y до:'no', после:0
# Элемент 40716: y до:'no', после:0
# Элемент 40717: y до:'no', после:0
# Элемент 40718: y до:'yes', после:1
# Элемент 40719: y до:'yes', после:1
# Элемент 40720: y до:'no', после:0
# Элемент 40721: y до:'no', после:0
# Элемент 40722: y до:'no', после:0
# Элемент 40723: y до:'yes', после:1
# Элемент 40724: y до:'yes', после:1
# Элемент 40725: y до:'no', после:0
# Элемент 40726: y до:'no', после:0
# Элемент 40727: y до:'no', после:0
# Элемент 40728: y до:'yes', после:1
# Элемент 40729: y до:'no', после:0
# Элемент 40730: y до:'no', после:0
# Элемент 40731: y до:'yes', после:1
# Элемент 40732: y до:'yes', после:1
# Элемент 40733: y до:'yes', после:1
# Элемент 40734: y до:'yes', после:1
# Элемент 40735: y до:'yes', после:1
# Элемент 40736: y до:'no', после:0
# Элемент 40737: y до:'no', после:0
# Элемент 40738: y до:'no', после:0
# Элемент 40739: y до:'no', после:0
# Элемент 40740: y до:'no', после:0
# Элемент 40741: y до:'no', после:0
# Элемент 40742: y до:'no', после:0
# Элемент 40743: y до:'no', после:0
# Элемент 40744: y до:'yes', после:1
# Элемент 40745: y до:'no', после:0
# Элемент 40746: y до:'no', после:0
# Элемент 40747: y до:'no', после:0
# Элемент 40748: y до:'no', после:0
# Элемент 40749: y до:'yes', после:1
# Элемент 40750: y до:'yes', после:1
# Элемент 40751: y до:'no', после:0
# Элемент 40752: y до:'yes', после:1
# Элемент 40753: y до:'no', после:0
# Элемент 40754: y до:'no', после:0
# Элемент 40755: y до:'no', после:0
# Элемент 40756: y до:'no', после:0
# Элемент 40757: y до:'yes', после:1
# Элемент 40758: y до:'no', после:0
# Элемент 40759: y до:'no', после:0
# Элемент 40760: y до:'no', после:0
# Элемент 40761: y до:'yes', после:1
# Элемент 40762: y до:'no', после:0
# Элемент 40763: y до:'yes', после:1
# Элемент 40764: y до:'no', после:0
# Элемент 40765: y до:'no', после:0
# Элемент 40766: y до:'no', после:0
# Элемент 40767: y до:'no', после:0
# Элемент 40768: y до:'no', после:0
# Элемент 40769: y до:'no', после:0
# Элемент 40770: y до:'no', после:0
# Элемент 40771: y до:'no', после:0
# Элемент 40772: y до:'no', после:0
# Элемент 40773: y до:'no', после:0
# Элемент 40774: y до:'no', после:0
# Элемент 40775: y до:'no', после:0
# Элемент 40776: y до:'no', после:0
# Элемент 40777: y до:'yes', после:1
# Элемент 40778: y до:'no', после:0
# Элемент 40779: y до:'yes', после:1
# Элемент 40780: y до:'no', после:0
# Элемент 40781: y до:'yes', после:1
# Элемент 40782: y до:'no', после:0
# Элемент 40783: y до:'no', после:0
# Элемент 40784: y до:'no', после:0
# Элемент 40785: y до:'no', после:0
# Элемент 40786: y до:'no', после:0
# Элемент 40787: y до:'no', после:0
# Элемент 40788: y до:'no', после:0
# Элемент 40789: y до:'no', после:0
# Элемент 40790: y до:'no', после:0
# Элемент 40791: y до:'no', после:0
# Элемент 40792: y до:'no', после:0
# Элемент 40793: y до:'yes', после:1
# Элемент 40794: y до:'no', после:0
# Элемент 40795: y до:'no', после:0
# Элемент 40796: y до:'no', после:0
# Элемент 40797: y до:'no', после:0
# Элемент 40798: y до:'no', после:0
# Элемент 40799: y до:'yes', после:1
# Элемент 40800: y до:'yes', после:1
# Элемент 40801: y до:'no', после:0
# Элемент 40802: y до:'no', после:0
# Элемент 40803: y до:'no', после:0
# Элемент 40804: y до:'no', после:0
# Элемент 40805: y до:'no', после:0
# Элемент 40806: y до:'no', после:0
# Элемент 40807: y до:'yes', после:1
# Элемент 40808: y до:'yes', после:1
# Элемент 40809: y до:'yes', после:1
# Элемент 40810: y до:'yes', после:1
# Элемент 40811: y до:'no', после:0
# Элемент 40812: y до:'yes', после:1
# Элемент 40813: y до:'yes', после:1
# Элемент 40814: y до:'no', после:0
# Элемент 40815: y до:'yes', после:1
# Элемент 40816: y до:'no', после:0
# Элемент 40817: y до:'no', после:0
# Элемент 40818: y до:'no', после:0
# Элемент 40819: y до:'no', после:0
# Элемент 40820: y до:'yes', после:1
# Элемент 40821: y до:'no', после:0
# Элемент 40822: y до:'no', после:0
# Элемент 40823: y до:'no', после:0
# Элемент 40824: y до:'yes', после:1
# Элемент 40825: y до:'yes', после:1
# Элемент 40826: y до:'no', после:0
# Элемент 40827: y до:'no', после:0
# Элемент 40828: y до:'yes', после:1
# Элемент 40829: y до:'yes', после:1
# Элемент 40830: y до:'no', после:0
# Элемент 40831: y до:'no', после:0
# Элемент 40832: y до:'no', после:0
# Элемент 40833: y до:'yes', после:1
# Элемент 40834: y до:'no', после:0
# Элемент 40835: y до:'yes', после:1
# Элемент 40836: y до:'no', после:0
# Элемент 40837: y до:'no', после:0
# Элемент 40838: y до:'no', после:0
# Элемент 40839: y до:'no', после:0
# Элемент 40840: y до:'yes', после:1
# Элемент 40841: y до:'no', после:0
# Элемент 40842: y до:'no', после:0
# Элемент 40843: y до:'no', после:0
# Элемент 40844: y до:'no', после:0
# Элемент 40845: y до:'no', после:0
# Элемент 40846: y до:'no', после:0
# Элемент 40847: y до:'no', после:0
# Элемент 40848: y до:'no', после:0
# Элемент 40849: y до:'no', после:0
# Элемент 40850: y до:'no', после:0
# Элемент 40851: y до:'no', после:0
# Элемент 40852: y до:'no', после:0
# Элемент 40853: y до:'yes', после:1
# Элемент 40854: y до:'yes', после:1
# Элемент 40855: y до:'no', после:0
# Элемент 40856: y до:'no', после:0
# Элемент 40857: y до:'yes', после:1
# Элемент 40858: y до:'no', после:0
# Элемент 40859: y до:'no', после:0
# Элемент 40860: y до:'no', после:0
# Элемент 40861: y до:'yes', после:1
# Элемент 40862: y до:'yes', после:1
# Элемент 40863: y до:'yes', после:1
# Элемент 40864: y до:'no', после:0
# Элемент 40865: y до:'yes', после:1
# Элемент 40866: y до:'no', после:0
# Элемент 40867: y до:'no', после:0
# Элемент 40868: y до:'yes', после:1
# Элемент 40869: y до:'yes', после:1
# Элемент 40870: y до:'no', после:0
# Элемент 40871: y до:'no', после:0
# Элемент 40872: y до:'yes', после:1
# Элемент 40873: y до:'yes', после:1
# Элемент 40874: y до:'yes', после:1
# Элемент 40875: y до:'no', после:0
# Элемент 40876: y до:'yes', после:1
# Элемент 40877: y до:'no', после:0
# Элемент 40878: y до:'yes', после:1
# Элемент 40879: y до:'yes', после:1
# Элемент 40880: y до:'no', после:0
# Элемент 40881: y до:'no', после:0
# Элемент 40882: y до:'no', после:0
# Элемент 40883: y до:'no', после:0
# Элемент 40884: y до:'yes', после:1
# Элемент 40885: y до:'no', после:0
# Элемент 40886: y до:'yes', после:1
# Элемент 40887: y до:'yes', после:1
# Элемент 40888: y до:'no', после:0
# Элемент 40889: y до:'yes', после:1
# Элемент 40890: y до:'no', после:0
# Элемент 40891: y до:'no', после:0
# Элемент 40892: y до:'no', после:0
# Элемент 40893: y до:'yes', после:1
# Элемент 40894: y до:'no', после:0
# Элемент 40895: y до:'no', после:0
# Элемент 40896: y до:'no', после:0
# Элемент 40897: y до:'no', после:0
# Элемент 40898: y до:'no', после:0
# Элемент 40899: y до:'no', после:0
# Элемент 40900: y до:'no', после:0
# Элемент 40901: y до:'no', после:0
# Элемент 40902: y до:'yes', после:1
# Элемент 40903: y до:'no', после:0
# Элемент 40904: y до:'yes', после:1
# Элемент 40905: y до:'no', после:0
# Элемент 40906: y до:'no', после:0
# Элемент 40907: y до:'no', после:0
# Элемент 40908: y до:'yes', после:1
# Элемент 40909: y до:'no', после:0
# Элемент 40910: y до:'no', после:0
# Элемент 40911: y до:'no', после:0
# Элемент 40912: y до:'no', после:0
# Элемент 40913: y до:'no', после:0
# Элемент 40914: y до:'no', после:0
# Элемент 40915: y до:'no', после:0
# Элемент 40916: y до:'no', после:0
# Элемент 40917: y до:'yes', после:1
# Элемент 40918: y до:'no', после:0
# Элемент 40919: y до:'no', после:0
# Элемент 40920: y до:'no', после:0
# Элемент 40921: y до:'no', после:0
# Элемент 40922: y до:'no', после:0
# Элемент 40923: y до:'no', после:0
# Элемент 40924: y до:'no', после:0
# Элемент 40925: y до:'yes', после:1
# Элемент 40926: y до:'no', после:0
# Элемент 40927: y до:'no', после:0
# Элемент 40928: y до:'no', после:0
# Элемент 40929: y до:'no', после:0
# Элемент 40930: y до:'no', после:0
# Элемент 40931: y до:'no', после:0
# Элемент 40932: y до:'no', после:0
# Элемент 40933: y до:'no', после:0
# Элемент 40934: y до:'no', после:0
# Элемент 40935: y до:'no', после:0
# Элемент 40936: y до:'no', после:0
# Элемент 40937: y до:'no', после:0
# Элемент 40938: y до:'no', после:0
# Элемент 40939: y до:'no', после:0
# Элемент 40940: y до:'yes', после:1
# Элемент 40941: y до:'no', после:0
# Элемент 40942: y до:'yes', после:1
# Элемент 40943: y до:'no', после:0
# Элемент 40944: y до:'no', после:0
# Элемент 40945: y до:'no', после:0
# Элемент 40946: y до:'no', после:0
# Элемент 40947: y до:'yes', после:1
# Элемент 40948: y до:'yes', после:1
# Элемент 40949: y до:'no', после:0
# Элемент 40950: y до:'no', после:0
# Элемент 40951: y до:'no', после:0
# Элемент 40952: y до:'yes', после:1
# Элемент 40953: y до:'no', после:0
# Элемент 40954: y до:'yes', после:1
# Элемент 40955: y до:'no', после:0
# Элемент 40956: y до:'no', после:0
# Элемент 40957: y до:'no', после:0
# Элемент 40958: y до:'yes', после:1
# Элемент 40959: y до:'no', после:0
# Элемент 40960: y до:'no', после:0
# Элемент 40961: y до:'yes', после:1
# Элемент 40962: y до:'no', после:0
# Элемент 40963: y до:'no', после:0
# Элемент 40964: y до:'yes', после:1
# Элемент 40965: y до:'no', после:0
# Элемент 40966: y до:'no', после:0
# Элемент 40967: y до:'no', после:0
# Элемент 40968: y до:'yes', после:1
# Элемент 40969: y до:'yes', после:1
# Элемент 40970: y до:'no', после:0
# Элемент 40971: y до:'yes', после:1
# Элемент 40972: y до:'no', после:0
# Элемент 40973: y до:'no', после:0
# Элемент 40974: y до:'no', после:0
# Элемент 40975: y до:'no', после:0
# Элемент 40976: y до:'no', после:0
# Элемент 40977: y до:'no', после:0
# Элемент 40978: y до:'no', после:0
# Элемент 40979: y до:'yes', после:1
# Элемент 40980: y до:'no', после:0
# Элемент 40981: y до:'no', после:0
# Элемент 40982: y до:'yes', после:1
# Элемент 40983: y до:'no', после:0
# Элемент 40984: y до:'yes', после:1
# Элемент 40985: y до:'no', после:0
# Элемент 40986: y до:'no', после:0
# Элемент 40987: y до:'yes', после:1
# Элемент 40988: y до:'no', после:0
# Элемент 40989: y до:'no', после:0
# Элемент 40990: y до:'no', после:0
# Элемент 40991: y до:'no', после:0
# Элемент 40992: y до:'no', после:0
# Элемент 40993: y до:'no', после:0
# Элемент 40994: y до:'no', после:0
# Элемент 40995: y до:'no', после:0
# Элемент 40996: y до:'no', после:0
# Элемент 40997: y до:'no', после:0
# Элемент 40998: y до:'yes', после:1
# Элемент 40999: y до:'no', после:0
# Элемент 41000: y до:'yes', после:1
# Элемент 41001: y до:'no', после:0
# Элемент 41002: y до:'no', после:0
# Элемент 41003: y до:'no', после:0
# Элемент 41004: y до:'no', после:0
# Элемент 41005: y до:'no', после:0
# Элемент 41006: y до:'no', после:0
# Элемент 41007: y до:'no', после:0
# Элемент 41008: y до:'no', после:0
# Элемент 41009: y до:'no', после:0
# Элемент 41010: y до:'no', после:0
# Элемент 41011: y до:'no', после:0
# Элемент 41012: y до:'no', после:0
# Элемент 41013: y до:'no', после:0
# Элемент 41014: y до:'yes', после:1
# Элемент 41015: y до:'no', после:0
# Элемент 41016: y до:'yes', после:1
# Элемент 41017: y до:'no', после:0
# Элемент 41018: y до:'no', после:0
# Элемент 41019: y до:'no', после:0
# Элемент 41020: y до:'yes', после:1
# Элемент 41021: y до:'yes', после:1
# Элемент 41022: y до:'yes', после:1
# Элемент 41023: y до:'no', после:0
# Элемент 41024: y до:'no', после:0
# Элемент 41025: y до:'no', после:0
# Элемент 41026: y до:'no', после:0
# Элемент 41027: y до:'no', после:0
# Элемент 41028: y до:'no', после:0
# Элемент 41029: y до:'no', после:0
# Элемент 41030: y до:'yes', после:1
# Элемент 41031: y до:'no', после:0
# Элемент 41032: y до:'yes', после:1
# Элемент 41033: y до:'no', после:0
# Элемент 41034: y до:'no', после:0
# Элемент 41035: y до:'yes', после:1
# Элемент 41036: y до:'no', после:0
# Элемент 41037: y до:'no', после:0
# Элемент 41038: y до:'yes', после:1
# Элемент 41039: y до:'yes', после:1
# Элемент 41040: y до:'no', после:0
# Элемент 41041: y до:'no', после:0
# Элемент 41042: y до:'no', после:0
# Элемент 41043: y до:'no', после:0
# Элемент 41044: y до:'no', после:0
# Элемент 41045: y до:'no', после:0
# Элемент 41046: y до:'no', после:0
# Элемент 41047: y до:'yes', после:1
# Элемент 41048: y до:'yes', после:1
# Элемент 41049: y до:'no', после:0
# Элемент 41050: y до:'no', после:0
# Элемент 41051: y до:'no', после:0
# Элемент 41052: y до:'yes', после:1
# Элемент 41053: y до:'no', после:0
# Элемент 41054: y до:'no', после:0
# Элемент 41055: y до:'no', после:0
# Элемент 41056: y до:'yes', после:1
# Элемент 41057: y до:'no', после:0
# Элемент 41058: y до:'no', после:0
# Элемент 41059: y до:'no', после:0
# Элемент 41060: y до:'no', после:0
# Элемент 41061: y до:'no', после:0
# Элемент 41062: y до:'yes', после:1
# Элемент 41063: y до:'no', после:0
# Элемент 41064: y до:'no', после:0
# Элемент 41065: y до:'yes', после:1
# Элемент 41066: y до:'yes', после:1
# Элемент 41067: y до:'no', после:0
# Элемент 41068: y до:'yes', после:1
# Элемент 41069: y до:'no', после:0
# Элемент 41070: y до:'yes', после:1
# Элемент 41071: y до:'yes', после:1
# Элемент 41072: y до:'yes', после:1
# Элемент 41073: y до:'yes', после:1
# Элемент 41074: y до:'no', после:0
# Элемент 41075: y до:'no', после:0
# Элемент 41076: y до:'no', после:0
# Элемент 41077: y до:'yes', после:1
# Элемент 41078: y до:'no', после:0
# Элемент 41079: y до:'yes', после:1
# Элемент 41080: y до:'yes', после:1
# Элемент 41081: y до:'no', после:0
# Элемент 41082: y до:'yes', после:1
# Элемент 41083: y до:'yes', после:1
# Элемент 41084: y до:'no', после:0
# Элемент 41085: y до:'yes', после:1
# Элемент 41086: y до:'no', после:0
# Элемент 41087: y до:'no', после:0
# Элемент 41088: y до:'no', после:0
# Элемент 41089: y до:'yes', после:1
# Элемент 41090: y до:'no', после:0
# Элемент 41091: y до:'no', после:0
# Элемент 41092: y до:'no', после:0
# Элемент 41093: y до:'no', после:0
# Элемент 41094: y до:'no', после:0
# Элемент 41095: y до:'yes', после:1
# Элемент 41096: y до:'no', после:0
# Элемент 41097: y до:'no', после:0
# Элемент 41098: y до:'no', после:0
# Элемент 41099: y до:'no', после:0
# Элемент 41100: y до:'yes', после:1
# Элемент 41101: y до:'yes', после:1
# Элемент 41102: y до:'no', после:0
# Элемент 41103: y до:'no', после:0
# Элемент 41104: y до:'yes', после:1
# Элемент 41105: y до:'no', после:0
# Элемент 41106: y до:'no', после:0
# Элемент 41107: y до:'yes', после:1
# Элемент 41108: y до:'no', после:0
# Элемент 41109: y до:'no', после:0
# Элемент 41110: y до:'no', после:0
# Элемент 41111: y до:'no', после:0
# Элемент 41112: y до:'no', после:0
# Элемент 41113: y до:'no', после:0
# Элемент 41114: y до:'no', после:0
# Элемент 41115: y до:'yes', после:1
# Элемент 41116: y до:'yes', после:1
# Элемент 41117: y до:'no', после:0
# Элемент 41118: y до:'no', после:0
# Элемент 41119: y до:'no', после:0
# Элемент 41120: y до:'no', после:0
# Элемент 41121: y до:'yes', после:1
# Элемент 41122: y до:'yes', после:1
# Элемент 41123: y до:'no', после:0
# Элемент 41124: y до:'no', после:0
# Элемент 41125: y до:'yes', после:1
# Элемент 41126: y до:'no', после:0
# Элемент 41127: y до:'no', после:0
# Элемент 41128: y до:'no', после:0
# Элемент 41129: y до:'no', после:0
# Элемент 41130: y до:'no', после:0
# Элемент 41131: y до:'yes', после:1
# Элемент 41132: y до:'no', после:0
# Элемент 41133: y до:'no', после:0
# Элемент 41134: y до:'yes', после:1
# Элемент 41135: y до:'yes', после:1
# Элемент 41136: y до:'no', после:0
# Элемент 41137: y до:'no', после:0
# Элемент 41138: y до:'no', после:0
# Элемент 41139: y до:'yes', после:1
# Элемент 41140: y до:'no', после:0
# Элемент 41141: y до:'no', после:0
# Элемент 41142: y до:'no', после:0
# Элемент 41143: y до:'yes', после:1
# Элемент 41144: y до:'no', после:0
# Элемент 41145: y до:'no', после:0
# Элемент 41146: y до:'yes', после:1
# Элемент 41147: y до:'yes', после:1
# Элемент 41148: y до:'yes', после:1
# Элемент 41149: y до:'yes', после:1
# Элемент 41150: y до:'no', после:0
# Элемент 41151: y до:'no', после:0
# Элемент 41152: y до:'no', после:0
# Элемент 41153: y до:'yes', после:1
# Элемент 41154: y до:'no', после:0
# Элемент 41155: y до:'no', после:0
# Элемент 41156: y до:'no', после:0
# Элемент 41157: y до:'no', после:0
# Элемент 41158: y до:'no', после:0
# Элемент 41159: y до:'yes', после:1
# Элемент 41160: y до:'no', после:0
# Элемент 41161: y до:'no', после:0
# Элемент 41162: y до:'no', после:0
# Элемент 41163: y до:'yes', после:1
# Элемент 41164: y до:'yes', после:1
# Элемент 41165: y до:'yes', после:1
# Элемент 41166: y до:'no', после:0
# Элемент 41167: y до:'no', после:0
# Элемент 41168: y до:'yes', после:1
# Элемент 41169: y до:'yes', после:1
# Элемент 41170: y до:'yes', после:1
# Элемент 41171: y до:'no', после:0
# Элемент 41172: y до:'yes', после:1
# Элемент 41173: y до:'yes', после:1
# Элемент 41174: y до:'yes', после:1
# Элемент 41175: y до:'no', после:0
# Элемент 41176: y до:'yes', после:1
# Элемент 41177: y до:'no', после:0
# Элемент 41178: y до:'no', после:0
# Элемент 41179: y до:'no', после:0
# Элемент 41180: y до:'yes', после:1
# Элемент 41181: y до:'no', после:0
# Элемент 41182: y до:'yes', после:1
# Элемент 41183: y до:'no', после:0
# Элемент 41184: y до:'yes', после:1
# Элемент 41185: y до:'yes', после:1
# Элемент 41186: y до:'yes', после:1
# Элемент 41187: y до:'no', после:0
# Элемент 41188: y до:'no', после:0
# Элемент 41189: y до:'yes', после:1
# Элемент 41190: y до:'no', после:0
# Элемент 41191: y до:'no', после:0
# Элемент 41192: y до:'no', после:0
# Элемент 41193: y до:'yes', после:1
# Элемент 41194: y до:'no', после:0
# Элемент 41195: y до:'no', после:0
# Элемент 41196: y до:'no', после:0
# Элемент 41197: y до:'no', после:0
# Элемент 41198: y до:'yes', после:1
# Элемент 41199: y до:'yes', после:1
# Элемент 41200: y до:'no', после:0
# Элемент 41201: y до:'yes', после:1
# Элемент 41202: y до:'no', после:0
# Элемент 41203: y до:'no', после:0
# Элемент 41204: y до:'yes', после:1
# Элемент 41205: y до:'yes', после:1
# Элемент 41206: y до:'no', после:0
# Элемент 41207: y до:'no', после:0
# Элемент 41208: y до:'yes', после:1
# Элемент 41209: y до:'no', после:0
# Элемент 41210: y до:'yes', после:1
# Элемент 41211: y до:'yes', после:1
# Элемент 41212: y до:'no', после:0
# Элемент 41213: y до:'no', после:0
# Элемент 41214: y до:'no', после:0
# Элемент 41215: y до:'no', после:0
# Элемент 41216: y до:'yes', после:1
# Элемент 41217: y до:'yes', после:1
# Элемент 41218: y до:'no', после:0
# Элемент 41219: y до:'no', после:0
# Элемент 41220: y до:'yes', после:1
# Элемент 41221: y до:'yes', после:1
# Элемент 41222: y до:'no', после:0
# Элемент 41223: y до:'no', после:0
# Элемент 41224: y до:'no', после:0
# Элемент 41225: y до:'no', после:0
# Элемент 41226: y до:'no', после:0
# Элемент 41227: y до:'yes', после:1
# Элемент 41228: y до:'yes', после:1
# Элемент 41229: y до:'no', после:0
# Элемент 41230: y до:'yes', после:1
# Элемент 41231: y до:'yes', после:1
# Элемент 41232: y до:'yes', после:1
# Элемент 41233: y до:'no', после:0
# Элемент 41234: y до:'yes', после:1
# Элемент 41235: y до:'no', после:0
# Элемент 41236: y до:'yes', после:1
# Элемент 41237: y до:'yes', после:1
# Элемент 41238: y до:'no', после:0
# Элемент 41239: y до:'no', после:0
# Элемент 41240: y до:'yes', после:1
# Элемент 41241: y до:'yes', после:1
# Элемент 41242: y до:'no', после:0
# Элемент 41243: y до:'no', после:0
# Элемент 41244: y до:'no', после:0
# Элемент 41245: y до:'yes', после:1
# Элемент 41246: y до:'yes', после:1
# Элемент 41247: y до:'no', после:0
# Элемент 41248: y до:'yes', после:1
# Элемент 41249: y до:'no', после:0
# Элемент 41250: y до:'no', после:0
# Элемент 41251: y до:'no', после:0
# Элемент 41252: y до:'no', после:0
# Элемент 41253: y до:'no', после:0
# Элемент 41254: y до:'no', после:0
# Элемент 41255: y до:'no', после:0
# Элемент 41256: y до:'no', после:0
# Элемент 41257: y до:'no', после:0
# Элемент 41258: y до:'no', после:0
# Элемент 41259: y до:'no', после:0
# Элемент 41260: y до:'no', после:0
# Элемент 41261: y до:'no', после:0
# Элемент 41262: y до:'no', после:0
# Элемент 41263: y до:'yes', после:1
# Элемент 41264: y до:'yes', после:1
# Элемент 41265: y до:'no', после:0
# Элемент 41266: y до:'no', после:0
# Элемент 41267: y до:'no', после:0
# Элемент 41268: y до:'no', после:0
# Элемент 41269: y до:'no', после:0
# Элемент 41270: y до:'no', после:0
# Элемент 41271: y до:'no', после:0
# Элемент 41272: y до:'no', после:0
# Элемент 41273: y до:'yes', после:1
# Элемент 41274: y до:'no', после:0
# Элемент 41275: y до:'yes', после:1
# Элемент 41276: y до:'yes', после:1
# Элемент 41277: y до:'no', после:0
# Элемент 41278: y до:'yes', после:1
# Элемент 41279: y до:'yes', после:1
# Элемент 41280: y до:'no', после:0
# Элемент 41281: y до:'no', после:0
# Элемент 41282: y до:'no', после:0
# Элемент 41283: y до:'yes', после:1
# Элемент 41284: y до:'no', после:0
# Элемент 41285: y до:'no', после:0
# Элемент 41286: y до:'yes', после:1
# Элемент 41287: y до:'yes', после:1
# Элемент 41288: y до:'no', после:0
# Элемент 41289: y до:'no', после:0
# Элемент 41290: y до:'no', после:0
# Элемент 41291: y до:'yes', после:1
# Элемент 41292: y до:'no', после:0
# Элемент 41293: y до:'yes', после:1
# Элемент 41294: y до:'yes', после:1
# Элемент 41295: y до:'yes', после:1
# Элемент 41296: y до:'yes', после:1
# Элемент 41297: y до:'yes', после:1
# Элемент 41298: y до:'no', после:0
# Элемент 41299: y до:'no', после:0
# Элемент 41300: y до:'yes', после:1
# Элемент 41301: y до:'no', после:0
# Элемент 41302: y до:'no', после:0
# Элемент 41303: y до:'yes', после:1
# Элемент 41304: y до:'no', после:0
# Элемент 41305: y до:'no', после:0
# Элемент 41306: y до:'yes', после:1
# Элемент 41307: y до:'yes', после:1
# Элемент 41308: y до:'no', после:0
# Элемент 41309: y до:'no', после:0
# Элемент 41310: y до:'yes', после:1
# Элемент 41311: y до:'yes', после:1
# Элемент 41312: y до:'no', после:0
# Элемент 41313: y до:'no', после:0
# Элемент 41314: y до:'yes', после:1
# Элемент 41315: y до:'yes', после:1
# Элемент 41316: y до:'no', после:0
# Элемент 41317: y до:'no', после:0
# Элемент 41318: y до:'no', после:0
# Элемент 41319: y до:'no', после:0
# Элемент 41320: y до:'yes', после:1
# Элемент 41321: y до:'no', после:0
# Элемент 41322: y до:'no', после:0
# Элемент 41323: y до:'no', после:0
# Элемент 41324: y до:'no', после:0
# Элемент 41325: y до:'no', после:0
# Элемент 41326: y до:'no', после:0
# Элемент 41327: y до:'no', после:0
# Элемент 41328: y до:'no', после:0
# Элемент 41329: y до:'no', после:0
# Элемент 41330: y до:'no', после:0
# Элемент 41331: y до:'no', после:0
# Элемент 41332: y до:'yes', после:1
# Элемент 41333: y до:'no', после:0
# Элемент 41334: y до:'yes', после:1
# Элемент 41335: y до:'yes', после:1
# Элемент 41336: y до:'no', после:0
# Элемент 41337: y до:'no', после:0
# Элемент 41338: y до:'yes', после:1
# Элемент 41339: y до:'no', после:0
# Элемент 41340: y до:'yes', после:1
# Элемент 41341: y до:'no', после:0
# Элемент 41342: y до:'no', после:0
# Элемент 41343: y до:'no', после:0
# Элемент 41344: y до:'yes', после:1
# Элемент 41345: y до:'yes', после:1
# Элемент 41346: y до:'no', после:0
# Элемент 41347: y до:'no', после:0
# Элемент 41348: y до:'no', после:0
# Элемент 41349: y до:'no', после:0
# Элемент 41350: y до:'no', после:0
# Элемент 41351: y до:'no', после:0
# Элемент 41352: y до:'no', после:0
# Элемент 41353: y до:'yes', после:1
# Элемент 41354: y до:'yes', после:1
# Элемент 41355: y до:'no', после:0
# Элемент 41356: y до:'no', после:0
# Элемент 41357: y до:'yes', после:1
# Элемент 41358: y до:'no', после:0
# Элемент 41359: y до:'no', после:0
# Элемент 41360: y до:'yes', после:1
# Элемент 41361: y до:'no', после:0
# Элемент 41362: y до:'no', после:0
# Элемент 41363: y до:'yes', после:1
# Элемент 41364: y до:'no', после:0
# Элемент 41365: y до:'yes', после:1
# Элемент 41366: y до:'no', после:0
# Элемент 41367: y до:'no', после:0
# Элемент 41368: y до:'yes', после:1
# Элемент 41369: y до:'no', после:0
# Элемент 41370: y до:'no', после:0
# Элемент 41371: y до:'yes', после:1
# Элемент 41372: y до:'no', после:0
# Элемент 41373: y до:'no', после:0
# Элемент 41374: y до:'no', после:0
# Элемент 41375: y до:'no', после:0
# Элемент 41376: y до:'no', после:0
# Элемент 41377: y до:'yes', после:1
# Элемент 41378: y до:'no', после:0
# Элемент 41379: y до:'no', после:0
# Элемент 41380: y до:'no', после:0
# Элемент 41381: y до:'no', после:0
# Элемент 41382: y до:'yes', после:1
# Элемент 41383: y до:'no', после:0
# Элемент 41384: y до:'no', после:0
# Элемент 41385: y до:'no', после:0
# Элемент 41386: y до:'no', после:0
# Элемент 41387: y до:'no', после:0
# Элемент 41388: y до:'no', после:0
# Элемент 41389: y до:'no', после:0
# Элемент 41390: y до:'yes', после:1
# Элемент 41391: y до:'yes', после:1
# Элемент 41392: y до:'yes', после:1
# Элемент 41393: y до:'yes', после:1
# Элемент 41394: y до:'no', после:0
# Элемент 41395: y до:'yes', после:1
# Элемент 41396: y до:'yes', после:1
# Элемент 41397: y до:'yes', после:1
# Элемент 41398: y до:'no', после:0
# Элемент 41399: y до:'yes', после:1
# Элемент 41400: y до:'no', после:0
# Элемент 41401: y до:'no', после:0
# Элемент 41402: y до:'no', после:0
# Элемент 41403: y до:'no', после:0
# Элемент 41404: y до:'yes', после:1
# Элемент 41405: y до:'yes', после:1
# Элемент 41406: y до:'no', после:0
# Элемент 41407: y до:'yes', после:1
# Элемент 41408: y до:'no', после:0
# Элемент 41409: y до:'no', после:0
# Элемент 41410: y до:'yes', после:1
# Элемент 41411: y до:'yes', после:1
# Элемент 41412: y до:'no', после:0
# Элемент 41413: y до:'no', после:0
# Элемент 41414: y до:'no', после:0
# Элемент 41415: y до:'no', после:0
# Элемент 41416: y до:'yes', после:1
# Элемент 41417: y до:'no', после:0
# Элемент 41418: y до:'yes', после:1
# Элемент 41419: y до:'no', после:0
# Элемент 41420: y до:'no', после:0
# Элемент 41421: y до:'no', после:0
# Элемент 41422: y до:'yes', после:1
# Элемент 41423: y до:'no', после:0
# Элемент 41424: y до:'no', после:0
# Элемент 41425: y до:'yes', после:1
# Элемент 41426: y до:'no', после:0
# Элемент 41427: y до:'yes', после:1
# Элемент 41428: y до:'yes', после:1
# Элемент 41429: y до:'no', после:0
# Элемент 41430: y до:'no', после:0
# Элемент 41431: y до:'no', после:0
# Элемент 41432: y до:'no', после:0
# Элемент 41433: y до:'no', после:0
# Элемент 41434: y до:'no', после:0
# Элемент 41435: y до:'no', после:0
# Элемент 41436: y до:'yes', после:1
# Элемент 41437: y до:'yes', после:1
# Элемент 41438: y до:'yes', после:1
# Элемент 41439: y до:'yes', после:1
# Элемент 41440: y до:'yes', после:1
# Элемент 41441: y до:'no', после:0
# Элемент 41442: y до:'no', после:0
# Элемент 41443: y до:'no', после:0
# Элемент 41444: y до:'yes', после:1
# Элемент 41445: y до:'no', после:0
# Элемент 41446: y до:'no', после:0
# Элемент 41447: y до:'no', после:0
# Элемент 41448: y до:'no', после:0
# Элемент 41449: y до:'no', после:0
# Элемент 41450: y до:'no', после:0
# Элемент 41451: y до:'yes', после:1
# Элемент 41452: y до:'yes', после:1
# Элемент 41453: y до:'yes', после:1
# Элемент 41454: y до:'no', после:0
# Элемент 41455: y до:'yes', после:1
# Элемент 41456: y до:'yes', после:1
# Элемент 41457: y до:'no', после:0
# Элемент 41458: y до:'no', после:0
# Элемент 41459: y до:'no', после:0
# Элемент 41460: y до:'no', после:0
# Элемент 41461: y до:'no', после:0
# Элемент 41462: y до:'no', после:0
# Элемент 41463: y до:'no', после:0
# Элемент 41464: y до:'no', после:0
# Элемент 41465: y до:'yes', после:1
# Элемент 41466: y до:'no', после:0
# Элемент 41467: y до:'no', после:0
# Элемент 41468: y до:'yes', после:1
# Элемент 41469: y до:'no', после:0
# Элемент 41470: y до:'no', после:0
# Элемент 41471: y до:'no', после:0
# Элемент 41472: y до:'yes', после:1
# Элемент 41473: y до:'yes', после:1
# Элемент 41474: y до:'no', после:0
# Элемент 41475: y до:'yes', после:1
# Элемент 41476: y до:'no', после:0
# Элемент 41477: y до:'no', после:0
# Элемент 41478: y до:'no', после:0
# Элемент 41479: y до:'no', после:0
# Элемент 41480: y до:'no', после:0
# Элемент 41481: y до:'yes', после:1
# Элемент 41482: y до:'yes', после:1
# Элемент 41483: y до:'no', после:0
# Элемент 41484: y до:'yes', после:1
# Элемент 41485: y до:'no', после:0
# Элемент 41486: y до:'yes', после:1
# Элемент 41487: y до:'yes', после:1
# Элемент 41488: y до:'no', после:0
# Элемент 41489: y до:'yes', после:1
# Элемент 41490: y до:'yes', после:1
# Элемент 41491: y до:'no', после:0
# Элемент 41492: y до:'yes', после:1
# Элемент 41493: y до:'yes', после:1
# Элемент 41494: y до:'yes', после:1
# Элемент 41495: y до:'no', после:0
# Элемент 41496: y до:'no', после:0
# Элемент 41497: y до:'yes', после:1
# Элемент 41498: y до:'yes', после:1
# Элемент 41499: y до:'yes', после:1
# Элемент 41500: y до:'no', после:0
# Элемент 41501: y до:'no', после:0
# Элемент 41502: y до:'yes', после:1
# Элемент 41503: y до:'yes', после:1
# Элемент 41504: y до:'no', после:0
# Элемент 41505: y до:'yes', после:1
# Элемент 41506: y до:'yes', после:1
# Элемент 41507: y до:'no', после:0
# Элемент 41508: y до:'yes', после:1
# Элемент 41509: y до:'yes', после:1
# Элемент 41510: y до:'yes', после:1
# Элемент 41511: y до:'yes', после:1
# Элемент 41512: y до:'yes', после:1
# Элемент 41513: y до:'no', после:0
# Элемент 41514: y до:'yes', после:1
# Элемент 41515: y до:'yes', после:1
# Элемент 41516: y до:'no', после:0
# Элемент 41517: y до:'no', после:0
# Элемент 41518: y до:'yes', после:1
# Элемент 41519: y до:'no', после:0
# Элемент 41520: y до:'no', после:0
# Элемент 41521: y до:'no', после:0
# Элемент 41522: y до:'no', после:0
# Элемент 41523: y до:'no', после:0
# Элемент 41524: y до:'no', после:0
# Элемент 41525: y до:'yes', после:1
# Элемент 41526: y до:'no', после:0
# Элемент 41527: y до:'no', после:0
# Элемент 41528: y до:'yes', после:1
# Элемент 41529: y до:'yes', после:1
# Элемент 41530: y до:'no', после:0
# Элемент 41531: y до:'yes', после:1
# Элемент 41532: y до:'yes', после:1
# Элемент 41533: y до:'no', после:0
# Элемент 41534: y до:'no', после:0
# Элемент 41535: y до:'no', после:0
# Элемент 41536: y до:'yes', после:1
# Элемент 41537: y до:'no', после:0
# Элемент 41538: y до:'no', после:0
# Элемент 41539: y до:'no', после:0
# Элемент 41540: y до:'no', после:0
# Элемент 41541: y до:'no', после:0
# Элемент 41542: y до:'yes', после:1
# Элемент 41543: y до:'no', после:0
# Элемент 41544: y до:'no', после:0
# Элемент 41545: y до:'no', после:0
# Элемент 41546: y до:'no', после:0
# Элемент 41547: y до:'yes', после:1
# Элемент 41548: y до:'no', после:0
# Элемент 41549: y до:'yes', после:1
# Элемент 41550: y до:'yes', после:1
# Элемент 41551: y до:'no', после:0
# Элемент 41552: y до:'yes', после:1
# Элемент 41553: y до:'no', после:0
# Элемент 41554: y до:'yes', после:1
# Элемент 41555: y до:'yes', после:1
# Элемент 41556: y до:'yes', после:1
# Элемент 41557: y до:'yes', после:1
# Элемент 41558: y до:'no', после:0
# Элемент 41559: y до:'yes', после:1
# Элемент 41560: y до:'yes', после:1
# Элемент 41561: y до:'yes', после:1
# Элемент 41562: y до:'yes', после:1
# Элемент 41563: y до:'no', после:0
# Элемент 41564: y до:'no', после:0
# Элемент 41565: y до:'no', после:0
# Элемент 41566: y до:'yes', после:1
# Элемент 41567: y до:'no', после:0
# Элемент 41568: y до:'no', после:0
# Элемент 41569: y до:'yes', после:1
# Элемент 41570: y до:'no', после:0
# Элемент 41571: y до:'yes', после:1
# Элемент 41572: y до:'yes', после:1
# Элемент 41573: y до:'yes', после:1
# Элемент 41574: y до:'yes', после:1
# Элемент 41575: y до:'yes', после:1
# Элемент 41576: y до:'yes', после:1
# Элемент 41577: y до:'yes', после:1
# Элемент 41578: y до:'yes', после:1
# Элемент 41579: y до:'yes', после:1
# Элемент 41580: y до:'no', после:0
# Элемент 41581: y до:'yes', после:1
# Элемент 41582: y до:'yes', после:1
# Элемент 41583: y до:'yes', после:1
# Элемент 41584: y до:'no', после:0
# Элемент 41585: y до:'yes', после:1
# Элемент 41586: y до:'no', после:0
# Элемент 41587: y до:'no', после:0
# Элемент 41588: y до:'yes', после:1
# Элемент 41589: y до:'yes', после:1
# Элемент 41590: y до:'no', после:0
# Элемент 41591: y до:'yes', после:1
# Элемент 41592: y до:'no', после:0
# Элемент 41593: y до:'no', после:0
# Элемент 41594: y до:'no', после:0
# Элемент 41595: y до:'yes', после:1
# Элемент 41596: y до:'yes', после:1
# Элемент 41597: y до:'no', после:0
# Элемент 41598: y до:'no', после:0
# Элемент 41599: y до:'no', после:0
# Элемент 41600: y до:'no', после:0
# Элемент 41601: y до:'no', после:0
# Элемент 41602: y до:'no', после:0
# Элемент 41603: y до:'yes', после:1
# Элемент 41604: y до:'no', после:0
# Элемент 41605: y до:'yes', после:1
# Элемент 41606: y до:'yes', после:1
# ...
# Элемент 44749: y до:'yes', после:1
# Элемент 44750: y до:'yes', после:1
# Элемент 44751: y до:'yes', после:1
# Элемент 44752: y до:'no', после:0
# Элемент 44753: y до:'no', после:0
# Элемент 44754: y до:'yes', после:1
# Элемент 44755: y до:'yes', после:1
# Элемент 44756: y до:'yes', после:1
# Элемент 44757: y до:'yes', после:1
# Элемент 44758: y до:'no', после:0
# Элемент 44759: y до:'yes', после:1
# Элемент 44760: y до:'yes', после:1
# Элемент 44761: y до:'no', после:0
# Элемент 44762: y до:'yes', после:1
# Элемент 44763: y до:'yes', после:1
# Элемент 44764: y до:'no', после:0
# Элемент 44765: y до:'yes', после:1
# Элемент 44766: y до:'no', после:0
# Элемент 44767: y до:'no', после:0
# Элемент 44768: y до:'no', после:0
# Элемент 44769: y до:'yes', после:1
# Элемент 44770: y до:'yes', после:1
# Элемент 44771: y до:'no', после:0
# Элемент 44772: y до:'yes', после:1
# Элемент 44773: y до:'no', после:0
# Элемент 44774: y до:'no', после:0
# Элемент 44775: y до:'no', после:0
# Элемент 44776: y до:'no', после:0
# Элемент 44777: y до:'no', после:0
# Элемент 44778: y до:'yes', после:1
# Элемент 44779: y до:'yes', после:1
# Элемент 44780: y до:'yes', после:1
# Элемент 44781: y до:'yes', после:1
# Элемент 44782: y до:'no', после:0
# Элемент 44783: y до:'yes', после:1
# Элемент 44784: y до:'yes', после:1
# Элемент 44785: y до:'no', после:0
# Элемент 44786: y до:'yes', после:1
# Элемент 44787: y до:'no', после:0
# Элемент 44788: y до:'yes', после:1
# Элемент 44789: y до:'no', после:0
# Элемент 44790: y до:'yes', после:1
# Элемент 44791: y до:'yes', после:1
# Элемент 44792: y до:'yes', после:1
# Элемент 44793: y до:'yes', после:1
# Элемент 44794: y до:'no', после:0
# Элемент 44795: y до:'yes', после:1
# Элемент 44796: y до:'yes', после:1
# Элемент 44797: y до:'yes', после:1
# Элемент 44798: y до:'yes', после:1
# Элемент 44799: y до:'no', после:0
# Элемент 44800: y до:'yes', после:1
# Элемент 44801: y до:'yes', после:1
# Элемент 44802: y до:'yes', после:1
# Элемент 44803: y до:'no', после:0
# Элемент 44804: y до:'no', после:0
# Элемент 44805: y до:'no', после:0
# Элемент 44806: y до:'no', после:0
# Элемент 44807: y до:'yes', после:1
# Элемент 44808: y до:'yes', после:1
# Элемент 44809: y до:'yes', после:1
# Элемент 44810: y до:'yes', после:1
# Элемент 44811: y до:'yes', после:1
# Элемент 44812: y до:'no', после:0
# Элемент 44813: y до:'yes', после:1
# Элемент 44814: y до:'yes', после:1
# Элемент 44815: y до:'yes', после:1
# Элемент 44816: y до:'yes', после:1
# Элемент 44817: y до:'yes', после:1
# Элемент 44818: y до:'no', после:0
# Элемент 44819: y до:'yes', после:1
# Элемент 44820: y до:'yes', после:1
# Элемент 44821: y до:'yes', после:1
# Элемент 44822: y до:'no', после:0
# Элемент 44823: y до:'yes', после:1
# Элемент 44824: y до:'yes', после:1
# Элемент 44825: y до:'no', после:0
# Элемент 44826: y до:'yes', после:1
# Элемент 44827: y до:'yes', после:1
# Элемент 44828: y до:'yes', после:1
# Элемент 44829: y до:'yes', после:1
# Элемент 44830: y до:'yes', после:1
# Элемент 44831: y до:'yes', после:1
# Элемент 44832: y до:'no', после:0
# Элемент 44833: y до:'no', после:0
# Элемент 44834: y до:'no', после:0
# Элемент 44835: y до:'yes', после:1
# Элемент 44836: y до:'no', после:0
# Элемент 44837: y до:'no', после:0
# Элемент 44838: y до:'no', после:0
# Элемент 44839: y до:'no', после:0
# Элемент 44840: y до:'no', после:0
# Элемент 44841: y до:'no', после:0
# Элемент 44842: y до:'no', после:0
# Элемент 44843: y до:'yes', после:1
# Элемент 44844: y до:'yes', после:1
# Элемент 44845: y до:'yes', после:1
# Элемент 44846: y до:'yes', после:1
# Элемент 44847: y до:'yes', после:1
# Элемент 44848: y до:'no', после:0
# Элемент 44849: y до:'no', после:0
# Элемент 44850: y до:'yes', после:1
# Элемент 44851: y до:'yes', после:1
# Элемент 44852: y до:'yes', после:1
# Элемент 44853: y до:'yes', после:1
# Элемент 44854: y до:'no', после:0
# Элемент 44855: y до:'yes', после:1
# Элемент 44856: y до:'yes', после:1
# Элемент 44857: y до:'yes', после:1
# Элемент 44858: y до:'yes', после:1
# Элемент 44859: y до:'no', после:0
# Элемент 44860: y до:'no', после:0
# Элемент 44861: y до:'no', после:0
# Элемент 44862: y до:'yes', после:1
# Элемент 44863: y до:'yes', после:1
# Элемент 44864: y до:'no', после:0
# Элемент 44865: y до:'yes', после:1
# Элемент 44866: y до:'no', после:0
# Элемент 44867: y до:'yes', после:1
# Элемент 44868: y до:'no', после:0
# Элемент 44869: y до:'yes', после:1
# Элемент 44870: y до:'no', после:0
# Элемент 44871: y до:'yes', после:1
# Элемент 44872: y до:'no', после:0
# Элемент 44873: y до:'no', после:0
# Элемент 44874: y до:'no', после:0
# Элемент 44875: y до:'no', после:0
# Элемент 44876: y до:'no', после:0
# Элемент 44877: y до:'yes', после:1
# Элемент 44878: y до:'no', после:0
# Элемент 44879: y до:'yes', после:1
# Элемент 44880: y до:'no', после:0
# Элемент 44881: y до:'yes', после:1
# Элемент 44882: y до:'no', после:0
# Элемент 44883: y до:'no', после:0
# Элемент 44884: y до:'yes', после:1
# Элемент 44885: y до:'yes', после:1
# Элемент 44886: y до:'no', после:0
# Элемент 44887: y до:'yes', после:1
# Элемент 44888: y до:'yes', после:1
# Элемент 44889: y до:'no', после:0
# Элемент 44890: y до:'no', после:0
# Элемент 44891: y до:'yes', после:1
# Элемент 44892: y до:'no', после:0
# Элемент 44893: y до:'yes', после:1
# Элемент 44894: y до:'no', после:0
# Элемент 44895: y до:'no', после:0
# Элемент 44896: y до:'no', после:0
# Элемент 44897: y до:'no', после:0
# Элемент 44898: y до:'yes', после:1
# Элемент 44899: y до:'no', после:0
# Элемент 44900: y до:'no', после:0
# Элемент 44901: y до:'no', после:0
# Элемент 44902: y до:'no', после:0
# Элемент 44903: y до:'yes', после:1
# Элемент 44904: y до:'yes', после:1
# Элемент 44905: y до:'no', после:0
# Элемент 44906: y до:'no', после:0
# Элемент 44907: y до:'no', после:0
# Элемент 44908: y до:'no', после:0
# Элемент 44909: y до:'no', после:0
# Элемент 44910: y до:'yes', после:1
# Элемент 44911: y до:'yes', после:1
# Элемент 44912: y до:'yes', после:1
# Элемент 44913: y до:'yes', после:1
# Элемент 44914: y до:'no', после:0
# Элемент 44915: y до:'no', после:0
# Элемент 44916: y до:'no', после:0
# Элемент 44917: y до:'no', после:0
# Элемент 44918: y до:'no', после:0
# Элемент 44919: y до:'no', после:0
# Элемент 44920: y до:'no', после:0
# Элемент 44921: y до:'no', после:0
# Элемент 44922: y до:'no', после:0
# Элемент 44923: y до:'no', после:0
# Элемент 44924: y до:'no', после:0
# Элемент 44925: y до:'no', после:0
# Элемент 44926: y до:'no', после:0
# Элемент 44927: y до:'no', после:0
# Элемент 44928: y до:'no', после:0
# Элемент 44929: y до:'no', после:0
# Элемент 44930: y до:'no', после:0
# Элемент 44931: y до:'yes', после:1
# Элемент 44932: y до:'yes', после:1
# Элемент 44933: y до:'yes', после:1
# Элемент 44934: y до:'yes', после:1
# Элемент 44935: y до:'yes', после:1
# Элемент 44936: y до:'no', после:0
# Элемент 44937: y до:'yes', после:1
# Элемент 44938: y до:'no', после:0
# Элемент 44939: y до:'no', после:0
# Элемент 44940: y до:'yes', после:1
# Элемент 44941: y до:'yes', после:1
# Элемент 44942: y до:'no', после:0
# Элемент 44943: y до:'no', после:0
# Элемент 44944: y до:'no', после:0
# Элемент 44945: y до:'no', после:0
# Элемент 44946: y до:'no', после:0
# Элемент 44947: y до:'no', после:0
# Элемент 44948: y до:'no', после:0
# Элемент 44949: y до:'no', после:0
# Элемент 44950: y до:'yes', после:1
# Элемент 44951: y до:'yes', после:1
# Элемент 44952: y до:'no', после:0
# Элемент 44953: y до:'no', после:0
# Элемент 44954: y до:'no', после:0
# Элемент 44955: y до:'no', после:0
# Элемент 44956: y до:'no', после:0
# Элемент 44957: y до:'no', после:0
# Элемент 44958: y до:'yes', после:1
# Элемент 44959: y до:'no', после:0
# Элемент 44960: y до:'yes', после:1
# Элемент 44961: y до:'yes', после:1
# Элемент 44962: y до:'yes', после:1
# Элемент 44963: y до:'no', после:0
# Элемент 44964: y до:'no', после:0
# Элемент 44965: y до:'no', после:0
# Элемент 44966: y до:'no', после:0
# Элемент 44967: y до:'no', после:0
# Элемент 44968: y до:'no', после:0
# Элемент 44969: y до:'no', после:0
# Элемент 44970: y до:'yes', после:1
# Элемент 44971: y до:'no', после:0
# Элемент 44972: y до:'yes', после:1
# Элемент 44973: y до:'yes', после:1
# Элемент 44974: y до:'no', после:0
# Элемент 44975: y до:'yes', после:1
# Элемент 44976: y до:'no', после:0
# Элемент 44977: y до:'yes', после:1
# Элемент 44978: y до:'no', после:0
# Элемент 44979: y до:'yes', после:1
# Элемент 44980: y до:'no', после:0
# Элемент 44981: y до:'no', после:0
# Элемент 44982: y до:'no', после:0
# Элемент 44983: y до:'no', после:0
# Элемент 44984: y до:'yes', после:1
# Элемент 44985: y до:'no', после:0
# Элемент 44986: y до:'no', после:0
# Элемент 44987: y до:'no', после:0
# Элемент 44988: y до:'no', после:0
# Элемент 44989: y до:'no', после:0
# Элемент 44990: y до:'yes', после:1
# Элемент 44991: y до:'yes', после:1
# Элемент 44992: y до:'no', после:0
# Элемент 44993: y до:'no', после:0
# Элемент 44994: y до:'yes', после:1
# Элемент 44995: y до:'no', после:0
# Элемент 44996: y до:'no', после:0
# Элемент 44997: y до:'no', после:0
# Элемент 44998: y до:'yes', после:1
# Элемент 44999: y до:'no', после:0
# Элемент 45000: y до:'no', после:0
# Элемент 45001: y до:'no', после:0
# Элемент 45002: y до:'yes', после:1
# Элемент 45003: y до:'yes', после:1
# Элемент 45004: y до:'yes', после:1
# Элемент 45005: y до:'yes', после:1
# Элемент 45006: y до:'yes', после:1
# Элемент 45007: y до:'no', после:0
# Элемент 45008: y до:'no', после:0
# Элемент 45009: y до:'no', после:0
# Элемент 45010: y до:'no', после:0
# Элемент 45011: y до:'yes', после:1
# Элемент 45012: y до:'yes', после:1
# Элемент 45013: y до:'yes', после:1
# Элемент 45014: y до:'no', после:0
# Элемент 45015: y до:'no', после:0
# Элемент 45016: y до:'no', после:0
# Элемент 45017: y до:'yes', после:1
# Элемент 45018: y до:'no', после:0
# Элемент 45019: y до:'no', после:0
# Элемент 45020: y до:'no', после:0
# Элемент 45021: y до:'no', после:0
# Элемент 45022: y до:'no', после:0
# Элемент 45023: y до:'no', после:0
# Элемент 45024: y до:'no', после:0
# Элемент 45025: y до:'no', после:0
# Элемент 45026: y до:'no', после:0
# Элемент 45027: y до:'no', после:0
# Элемент 45028: y до:'yes', после:1
# Элемент 45029: y до:'no', после:0
# Элемент 45030: y до:'no', после:0
# Элемент 45031: y до:'yes', после:1
# Элемент 45032: y до:'no', после:0
# Элемент 45033: y до:'no', после:0
# Элемент 45034: y до:'no', после:0
# Элемент 45035: y до:'yes', после:1
# Элемент 45036: y до:'no', после:0
# Элемент 45037: y до:'yes', после:1
# Элемент 45038: y до:'yes', после:1
# Элемент 45039: y до:'yes', после:1
# Элемент 45040: y до:'yes', после:1
# Элемент 45041: y до:'no', после:0
# Элемент 45042: y до:'yes', после:1
# Элемент 45043: y до:'yes', после:1
# Элемент 45044: y до:'no', после:0
# Элемент 45045: y до:'no', после:0
# Элемент 45046: y до:'yes', после:1
# Элемент 45047: y до:'no', после:0
# Элемент 45048: y до:'no', после:0
# Элемент 45049: y до:'no', после:0
# Элемент 45050: y до:'no', после:0
# Элемент 45051: y до:'no', после:0
# Элемент 45052: y до:'yes', после:1
# Элемент 45053: y до:'no', после:0
# Элемент 45054: y до:'no', после:0
# Элемент 45055: y до:'yes', после:1
# Элемент 45056: y до:'yes', после:1
# Элемент 45057: y до:'yes', после:1
# Элемент 45058: y до:'yes', после:1
# Элемент 45059: y до:'no', после:0
# Элемент 45060: y до:'yes', после:1
# Элемент 45061: y до:'no', после:0
# Элемент 45062: y до:'no', после:0
# Элемент 45063: y до:'no', после:0
# Элемент 45064: y до:'no', после:0
# Элемент 45065: y до:'no', после:0
# Элемент 45066: y до:'yes', после:1
# Элемент 45067: y до:'yes', после:1
# Элемент 45068: y до:'no', после:0
# Элемент 45069: y до:'yes', после:1
# Элемент 45070: y до:'no', после:0
# Элемент 45071: y до:'yes', после:1
# Элемент 45072: y до:'yes', после:1
# Элемент 45073: y до:'yes', после:1
# Элемент 45074: y до:'yes', после:1
# Элемент 45075: y до:'yes', после:1
# Элемент 45076: y до:'no', после:0
# Элемент 45077: y до:'no', после:0
# Элемент 45078: y до:'yes', после:1
# Элемент 45079: y до:'yes', после:1
# Элемент 45080: y до:'no', после:0
# Элемент 45081: y до:'yes', после:1
# Элемент 45082: y до:'no', после:0
# Элемент 45083: y до:'yes', после:1
# Элемент 45084: y до:'yes', после:1
# Элемент 45085: y до:'yes', после:1
# Элемент 45086: y до:'yes', после:1
# Элемент 45087: y до:'no', после:0
# Элемент 45088: y до:'no', после:0
# Элемент 45089: y до:'no', после:0
# Элемент 45090: y до:'yes', после:1
# Элемент 45091: y до:'no', после:0
# Элемент 45092: y до:'yes', после:1
# Элемент 45093: y до:'yes', после:1
# Элемент 45094: y до:'yes', после:1
# Элемент 45095: y до:'no', после:0
# Элемент 45096: y до:'yes', после:1
# Элемент 45097: y до:'yes', после:1
# Элемент 45098: y до:'no', после:0
# Элемент 45099: y до:'yes', после:1
# Элемент 45100: y до:'no', после:0
# Элемент 45101: y до:'yes', после:1
# Элемент 45102: y до:'yes', после:1
# Элемент 45103: y до:'yes', после:1
# Элемент 45104: y до:'no', после:0
# Элемент 45105: y до:'no', после:0
# Элемент 45106: y до:'yes', после:1
# Элемент 45107: y до:'yes', после:1
# Элемент 45108: y до:'no', после:0
# Элемент 45109: y до:'yes', после:1
# Элемент 45110: y до:'no', после:0
# Элемент 45111: y до:'no', после:0
# Элемент 45112: y до:'no', после:0
# Элемент 45113: y до:'yes', после:1
# Элемент 45114: y до:'no', после:0
# Элемент 45115: y до:'no', после:0
# Элемент 45116: y до:'yes', после:1
# Элемент 45117: y до:'no', после:0
# Элемент 45118: y до:'no', после:0
# Элемент 45119: y до:'yes', после:1
# Элемент 45120: y до:'yes', после:1
# Элемент 45121: y до:'yes', после:1
# Элемент 45122: y до:'no', после:0
# Элемент 45123: y до:'no', после:0
# Элемент 45124: y до:'yes', после:1
# Элемент 45125: y до:'yes', после:1
# Элемент 45126: y до:'yes', после:1
# Элемент 45127: y до:'no', после:0
# Элемент 45128: y до:'no', после:0
# Элемент 45129: y до:'yes', после:1
# Элемент 45130: y до:'no', после:0
# Элемент 45131: y до:'yes', после:1
# Элемент 45132: y до:'no', после:0
# Элемент 45133: y до:'yes', после:1
# Элемент 45134: y до:'yes', после:1
# Элемент 45135: y до:'no', после:0
# Элемент 45136: y до:'no', после:0
# Элемент 45137: y до:'yes', после:1
# Элемент 45138: y до:'no', после:0
# Элемент 45139: y до:'no', после:0
# Элемент 45140: y до:'yes', после:1
# Элемент 45141: y до:'no', после:0
# Элемент 45142: y до:'no', после:0
# Элемент 45143: y до:'no', после:0
# Элемент 45144: y до:'no', после:0
# Элемент 45145: y до:'no', после:0
# Элемент 45146: y до:'no', после:0
# Элемент 45147: y до:'no', после:0
# Элемент 45148: y до:'yes', после:1
# Элемент 45149: y до:'yes', после:1
# Элемент 45150: y до:'no', после:0
# Элемент 45151: y до:'no', после:0
# Элемент 45152: y до:'no', после:0
# Элемент 45153: y до:'no', после:0
# Элемент 45154: y до:'no', после:0
# Элемент 45155: y до:'yes', после:1
# Элемент 45156: y до:'yes', после:1
# Элемент 45157: y до:'yes', после:1
# Элемент 45158: y до:'no', после:0
# Элемент 45159: y до:'no', после:0
# Элемент 45160: y до:'yes', после:1
# Элемент 45161: y до:'no', после:0
# Элемент 45162: y до:'yes', после:1
# Элемент 45163: y до:'no', после:0
# Элемент 45164: y до:'no', после:0
# Элемент 45165: y до:'no', после:0
# Элемент 45166: y до:'yes', после:1
# Элемент 45167: y до:'no', после:0
# Элемент 45168: y до:'yes', после:1
# Элемент 45169: y до:'no', после:0
# Элемент 45170: y до:'no', после:0
# Элемент 45171: y до:'no', после:0
# Элемент 45172: y до:'no', после:0
# Элемент 45173: y до:'no', после:0
# Элемент 45174: y до:'yes', после:1
# Элемент 45175: y до:'yes', после:1
# Элемент 45176: y до:'yes', после:1
# Элемент 45177: y до:'yes', после:1
# Элемент 45178: y до:'yes', после:1
# Элемент 45179: y до:'no', после:0
# Элемент 45180: y до:'no', после:0
# Элемент 45181: y до:'no', после:0
# Элемент 45182: y до:'yes', после:1
# Элемент 45183: y до:'no', после:0
# Элемент 45184: y до:'no', после:0
# Элемент 45185: y до:'yes', после:1
# Элемент 45186: y до:'no', после:0
# Элемент 45187: y до:'yes', после:1
# Элемент 45188: y до:'yes', после:1
# Элемент 45189: y до:'no', после:0
# Элемент 45190: y до:'yes', после:1
# Элемент 45191: y до:'yes', после:1
# Элемент 45192: y до:'yes', после:1
# Элемент 45193: y до:'yes', после:1
# Элемент 45194: y до:'no', после:0
# Элемент 45195: y до:'yes', после:1
# Элемент 45196: y до:'yes', после:1
# Элемент 45197: y до:'yes', после:1
# Элемент 45198: y до:'no', после:0
# Элемент 45199: y до:'no', после:0
# Элемент 45200: y до:'yes', после:1
# Элемент 45201: y до:'yes', после:1
# Элемент 45202: y до:'yes', после:1
# Элемент 45203: y до:'yes', после:1
# Элемент 45204: y до:'yes', после:1
# Элемент 45205: y до:'yes', после:1
# Элемент 45206: y до:'yes', после:1
# Элемент 45207: y до:'yes', после:1
# Элемент 45208: y до:'yes', после:1
# Элемент 45209: y до:'no', после:0
# Элемент 45210: y до:'no', после:0
# Информация о кодировании меток:
# {'no': 0, 'yes': 1}

# %% [markdown]
# <p class="task" id="5"></p>
#
# 5\. Опишите класс `ToTensor`.  Решение должно удовлетворять следующим критериям:
# * класс реализует интерфейс `Callable` (`__call__`); метод `__call__` принимает на вход серию или фрейм и возвращает тензор.
#
# Опишите класс `Compose`.  Решение должно удовлетворять следующим критериям:
# * при создании объекта в конструктор передается список объектов `transforms`, каждый из которых имеет метод `__call__(x, y)`;
# * класс реализует интерфейс `Callable` (`__call__`); метод `__call__` принимает имеет параметра (признаки и класс в числовом виде) и и возвращает кортеж, полученный путем последовательного вызова объектов из `transforms`.
#
# Продемонстрируйте работоспособность, создав объект `BankDataset` и передав при создании преобразования `Compose` список из объектов LabelEncoderTransform и ToTensor.
#
# - [ ] Проверено на семинаре

# %%
import torch as th
from typing import Any

class ToTensor(Transform):
    def __call__(self, X: pd.Series | int) -> th.Tensor:
        pass

class Compose(Transform):
    def __init__(self, transforms: list[Transform]) -> None:
        pass

    def __call__(self, X: Any) -> Any:
        pass

# %%
import torch as th
from typing import Any

class Transform:
    pass

class ToTensor(Transform):
    def __call__(self, x: pd.Series | int) -> th.Tensor:
        if isinstance(x, pd.Series):
            return th.tensor(x.values, dtype=th.float32)
        elif isinstance(x, int):
            return th.tensor(x, dtype=th.int64)

# %%
class Compose(Transform):
    def __init__(self, transforms: list[Transform]) -> None:
        self.transforms = transforms

    def __call__(self, x: Any) -> Any:
        for transform in self.transforms:
            x = transform(x)
        return x

# %%
label_encoder = LabelEncoderTransform()
to_tensor = ToTensor()
target_transforms = Compose(transforms=[label_encoder, to_tensor])

bank_dataset_composed = BankDataset(
    data=df,
    target_transform=target_transforms
)

original_label = df.loc[0, 'y']
_, encoded_label = bank_dataset_composed[0]
print(f"Оригинальная метка: '{original_label}', Преобразованная метка: {encoded_label}")
print(f"Тип данных: {encoded_label.dtype}")
print(f"Словарь кодирования: {label_encoder.get_encoding_info()}")
# Out:
# Оригинальная метка: 'no', Преобразованная метка: 0
# Тип данных: torch.int64
# Словарь кодирования: {'no': 0}

# %% [markdown]
# <p class="task" id="6"></p>
#
# 6\. Разделите датасет из предыдущего задания на обучающую и тестовую выборку в соотношении 75% на 25%. Создайте объект `DataLoader` для получения пакетов размера 64, полученных из перемешанного обучающего датасета. Кастомизируйте `DataLoader` таким образом, чтобы пакет признаков был представлен в виде трехмерного тензора размера 64x2x8 (разделите 16 признаков на два тензора по 8). Получите один пакет и выведите на экран размерность тензоров пакета.
#
# - [ ] Проверено на семинаре

# %%
import pandas as pd
import torch as th
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from typing import Callable, Any

class Transform:
    pass

class BankDataset(Dataset):
    def __init__(self, data: pd.DataFrame, transform: Callable | None = None, target_transform: Callable | None = None) -> None:
        self.X = data.drop(columns=['y'])
        self.y = data['y']
        self.transform = transform
        self.target_transform = target_transform
    def __getitem__(self, idx: int) -> tuple:
        x = self.X.iloc[idx]
        y = self.y.iloc[idx]
        if self.transform:
            x = self.transform(x)
        if self.target_transform:
            y = self.target_transform(y)
        return x, y
    def __len__(self) -> int:
        return len(self.X)

class OrdinalEncoderTransform(Transform):
    def __init__(self, category_columns: list[str]) -> None:
        self.category_columns = category_columns
        self.encoding_dict = {}
        self.next_code = {col: 0 for col in category_columns}
    def __call__(self, x: pd.Series) -> pd.Series:
        x_transformed = x.copy()
        for col in self.category_columns:
            if col in x_transformed.index:
                category = x_transformed[col]
                if category not in self.encoding_dict.get(col, {}):
                    if col not in self.encoding_dict:
                        self.encoding_dict[col] = {}
                    self.encoding_dict[col][category] = self.next_code[col]
                    self.next_code[col] += 1
                x_transformed[col] = self.encoding_dict[col][category]
        return x_transformed.astype(float)

class LabelEncoderTransform(Transform):
    def __init__(self) -> None:
        self.encoding_dict = {}
        self.next_index = 0
    def __call__(self, label: str) -> int:
        if label not in self.encoding_dict:
            self.encoding_dict[label] = self.next_index
            self.next_index += 1
        return self.encoding_dict[label]
    def get_encoding_info(self) -> dict:
        return self.encoding_dict.copy()

class ToTensor(Transform):
    def __call__(self, x: pd.Series | int) -> th.Tensor:
        if isinstance(x, pd.Series):
            return th.tensor(x.values, dtype=th.float32)
        elif isinstance(x, int):
            return th.tensor(x, dtype=th.int64)
        else:
            raise TypeError("Unsupported data type for ToTensor")

class Compose(Transform):
    def __init__(self, transforms: list[Transform]) -> None:
        self.transforms = transforms
    def __call__(self, x: Any) -> Any:
        for transform in self.transforms:
            x = transform(x)
        return x

df = pd.read_csv('bank-full.csv', sep=',')
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']

encoder_features = OrdinalEncoderTransform(category_columns=categorical_cols)
encoder_target = LabelEncoderTransform()
to_tensor = ToTensor()

feature_transforms = Compose(transforms=[encoder_features, to_tensor])
target_transforms = Compose(transforms=[encoder_target, to_tensor])

train_df, test_df = train_test_split(df, test_size=0.25, random_state=42)

train_dataset = BankDataset(
    data=train_df,
    transform=feature_transforms,
    target_transform=target_transforms
)

def custom_collate_fn(batch):
    features = [item[0] for item in batch]
    labels = [item[1] for item in batch]

    features_tensor = th.stack(features)
    labels_tensor = th.stack(labels)

    features_tensor_reshaped = features_tensor.view(-1, 2, 8)

    return features_tensor_reshaped, labels_tensor

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=64,
    shuffle=True,
    collate_fn=custom_collate_fn
)
batch_features, batch_labels = next(iter(train_loader))

print(f"Размерность тензора признаков: {batch_features.shape}")
print(f"Размерность тензора меток: {batch_labels.shape}")
# Out:
# Размерность тензора признаков: torch.Size([64, 2, 8])
# Размерность тензора меток: torch.Size([64])

# %%
batch_features
# Out:
# tensor([[[ 2.9000e+01,  0.0000e+00,  0.0000e+00,  ...,  2.4700e+02,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  7.0000e+00,  0.0000e+00,  ..., -1.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 4.1000e+01,  1.0000e+00,  1.0000e+00,  ...,  6.4600e+02,
#            1.0000e+00,  1.0000e+00],
#          [ 1.0000e+00,  2.9000e+01,  1.0000e+00,  ..., -1.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 3.0000e+01,  2.0000e+00,  0.0000e+00,  ...,  1.5670e+03,
#            1.0000e+00,  1.0000e+00],
#          [ 0.0000e+00,  1.2000e+01,  2.0000e+00,  ..., -1.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         ...,
#
#         [[ 2.7000e+01,  2.0000e+00,  1.0000e+00,  ...,  1.0200e+02,
#            0.0000e+00,  1.0000e+00],
#          [ 1.0000e+00,  2.6000e+01,  0.0000e+00,  ..., -1.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 5.7000e+01,  2.0000e+00,  0.0000e+00,  ...,  1.3410e+03,
#            1.0000e+00,  1.0000e+00],
#          [ 1.0000e+00,  8.0000e+00,  1.0000e+00,  ..., -1.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 3.5000e+01,  0.0000e+00,  0.0000e+00,  ...,  2.7370e+03,
#            1.0000e+00,  1.0000e+00],
#          [ 0.0000e+00,  1.3000e+01,  1.0000e+00,  ..., -1.0000e+00,
#            0.0000e+00,  0.0000e+00]]])
